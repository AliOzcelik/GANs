# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable
import torchvision
from torch.utils.data import DataLoader
import time

# %%
batch_size = 64
image_size = 64

transform = torchvision.transforms.Compose([torchvision.transforms.Resize(image_size), torchvision.transforms.ToTensor(), torchvision.transforms.Normalize(0.5, 0.5)])

path = r"/Users/desidero/Desktop/Kodlar/GANs/mnist_torch/"
dataset = torchvision.datasets.MNIST(root=path, train=False, download=True, transform=transform)
data = DataLoader(dataset, batch_size=batch_size, shuffle=True)

# %%
for image, label in data:
    print(image.shape)
    print(label.shape)
    break
# Out:
# torch.Size([64, 1, 64, 64])
# torch.Size([64])

# %%
def weights_init(m):
    classname = m.__class__.__name__
    if classname.find('Conv') != -1:
        m.weight.data.normal_(0.0, 0.02)
    elif classname.find('BatchNorm') != -1:
        m.weight.data.normal_(1.0, 0.02)
        m.bias.data.fill_

# %%
class Generator(nn.Module):

    def __init__(self):
        super(Generator, self).__init__()
        self.main = nn.Sequential(
            nn.ConvTranspose2d(100, 512, 4, 1, 0, bias=False),
            nn.BatchNorm2d(512),
            nn.ReLU(True),
            nn.ConvTranspose2d(512, 256, 4, 2, 1, bias=False),
            nn.BatchNorm2d(256),
            nn.ReLU(True),
            nn.ConvTranspose2d(256, 128, 4, 2, 1, bias=False),
            nn.BatchNorm2d(128),
            nn.ReLU(True),
            nn.ConvTranspose2d(128, 64, 4, 2, 1, bias=False),
            nn.BatchNorm2d(64),
            nn.ReLU(True),
            nn.ConvTranspose2d(64, 1, 4, 2, 1, bias=False),
            nn.Tanh()
            )

    def forward(self, x):
        return self.main(x)

# %%
class Discriminator(nn.Module):

    def __init__(self):
        super(Discriminator, self).__init__()
        self.main = nn.Sequential(
            nn.Conv2d(1, 64, 4, 2, 1, bias=False),
            nn.LeakyReLU(negative_slope=0.2, inplace=True),
            nn.Conv2d(64, 128, 4, 2, 1, bias=False),
            nn.BatchNorm2d(128),
            nn.LeakyReLU(negative_slope=0.2, inplace=True),
            nn.Conv2d(128, 256, 4, 2, 1, bias=False),
            nn.BatchNorm2d(256),
            nn.LeakyReLU(negative_slope=0.2, inplace=True),
            nn.Conv2d(256, 512, 4, 2, 1, bias=False),
            nn.BatchNorm2d(512),
            nn.LeakyReLU(negative_slope=0.2, inplace=True),
            nn.Conv2d(512, 1, 4, 1, 0, bias=False), # discriminating a number between 0 and 1, so out_channel=1
            nn.Sigmoid() # because sigmoid returns a value between 0 and 1
            )

    def forward(self, x):
        output = self.main(x)
        return output.view(-1)

# %%
device = torch.device('mps')

# %%
gen = Generator().to(device)
disc = Discriminator().to(device)

gen.apply(weights_init) # .apply method applies a function on class
disc.apply(weights_init) # .apply method applies a function on class

criterion = nn.BCELoss()
gen_optim = torch.optim.Adam(gen.parameters(), lr=0.0002, betas=(0.5, 0.999))
disc_optim = torch.optim.Adam(disc.parameters(), lr=0.0002, betas=(0.5, 0.999))

# %%
epochs = 100
liste = [i+1 for i in range(epochs)]
j = 0
for epoch in range(epochs):
    print("Epoch: {}".format(epoch))
    for real, label in data: # i will start from 0
       
        # Step 1: Updating the weights of the discriminator 
        disc.zero_grad()
        #print(data.shape)
        # Training the discriminator with a real image of the dataset
        #real, label = data
        real = real.to(device)
        #label = label.to(device)
        input_real = Variable(real)
        target = Variable(torch.ones(input_real.size()[0])).to(device) # target should be 1 because this images are real images
        output = disc.forward(input_real).to(device)
        disc_loss_real = criterion(output, target).to(device)
        
        # Training the discriminator with a fake image generated by the generator
        noise = Variable(torch.randn(input_real.size()[0], 100, 1, 1)).to(device) # giving fake dimensions with 1,1 after 100
        fake = gen.forward(noise).to(device)
        target = Variable(torch.zeros(input_real.size()[0])).to(device) # target should be 1 because this images are fake images
        output = disc.forward(fake.detach()) # .detach to save some cmemory and make the training faster
        disc_loss_fake = criterion(output, target).to(device)

        # Backpropogating the total error
        disc_loss = disc_loss_real + disc_loss_fake
        disc_loss.backward()
        disc_optim.step()

        # Step 2: Updating the weights of the generator
        gen.zero_grad()
        target = Variable(torch.ones(input_real.size()[0])).to(device)
        output = disc.forward(fake).to(device)
        gen_loss = criterion(output, target).to(device)
        gen_loss.backward()
        gen_optim.step()        

        # Step 3: Printing the losses, then saving the real and generated images of the minibatch every 100 steps
        print("Loss_D: %.4f, Loss_G: %.4f" % (disc_loss, gen_loss))
    torchvision.utils.save_image(real, '%s/real_samples_{}.png'.format(liste[j]) %  r"/Users/desidero/Desktop/Kodlar/GANs/mnist_torch/", normalize=True)
    fake = gen.forward(noise)
    torchvision.utils.save_image(fake.data, '%s/fake_samples_{}.png'.format(liste[j]) % r"/Users/desidero/Desktop/Kodlar/GANs/mnist_torch/", normalize=True)
    j += 1
# Out:
# Epoch: 0
# Loss_D: 0.0486, Loss_G: 6.6606
# Loss_D: 0.2645, Loss_G: 6.1163
# Loss_D: 0.4816, Loss_G: 7.6838
# Loss_D: 0.2502, Loss_G: 7.1517
# Loss_D: 0.1670, Loss_G: 6.7131
# Loss_D: 0.1766, Loss_G: 8.0779
# Loss_D: 0.0464, Loss_G: 7.7084
# Loss_D: 0.0961, Loss_G: 7.1896
# Loss_D: 0.0954, Loss_G: 8.1389
# Loss_D: 0.0792, Loss_G: 7.8709
# Loss_D: 0.0888, Loss_G: 8.9995
# Loss_D: 0.0930, Loss_G: 7.5884
# Loss_D: 0.2705, Loss_G: 13.8748
# Loss_D: 0.2078, Loss_G: 10.5491
# Loss_D: 0.0362, Loss_G: 6.6309
# Loss_D: 0.9136, Loss_G: 21.1447
# Loss_D: 2.0457, Loss_G: 15.1089
# Loss_D: 0.0151, Loss_G: 4.4071
# Loss_D: 5.6032, Loss_G: 18.2590
# Loss_D: 0.1946, Loss_G: 20.6413
# Loss_D: 0.2542, Loss_G: 14.5471
# Loss_D: 0.2302, Loss_G: 5.1781
# Loss_D: 2.4797, Loss_G: 21.0998
# Loss_D: 0.7420, Loss_G: 22.7621
# Loss_D: 0.0913, Loss_G: 18.1244
# Loss_D: 0.0568, Loss_G: 9.3338
# Loss_D: 0.1631, Loss_G: 8.5966
# Loss_D: 0.1463, Loss_G: 11.1993
# Loss_D: 0.0348, Loss_G: 9.2814
# Loss_D: 0.1774, Loss_G: 10.4494
# Loss_D: 0.1362, Loss_G: 8.5581
# Loss_D: 0.1519, Loss_G: 10.0213
# Loss_D: 0.1001, Loss_G: 8.4788
# Loss_D: 0.0611, Loss_G: 7.3675
# Loss_D: 0.1527, Loss_G: 9.8285
# Loss_D: 0.0507, Loss_G: 8.5744
# Loss_D: 0.1375, Loss_G: 7.1557
# Loss_D: 0.1372, Loss_G: 12.1940
# Loss_D: 0.0804, Loss_G: 11.5011
# Loss_D: 0.0591, Loss_G: 8.0358
# Loss_D: 0.0705, Loss_G: 8.5924
# Loss_D: 0.0707, Loss_G: 9.5706
# Loss_D: 0.0556, Loss_G: 8.2755
# Loss_D: 0.0712, Loss_G: 8.3074
# Loss_D: 0.0441, Loss_G: 8.8680
# Loss_D: 0.0412, Loss_G: 8.1169
# Loss_D: 0.0679, Loss_G: 8.1298
# Loss_D: 0.0444, Loss_G: 8.4306
# Loss_D: 0.0631, Loss_G: 7.6512
# Loss_D: 0.1069, Loss_G: 9.0972
# Loss_D: 0.0136, Loss_G: 8.5462
# Loss_D: 0.0189, Loss_G: 7.3048
# Loss_D: 0.0407, Loss_G: 8.0350
# Loss_D: 0.0198, Loss_G: 8.0368
# Loss_D: 0.0229, Loss_G: 7.6182
# Loss_D: 0.0568, Loss_G: 7.1835
# Loss_D: 0.0750, Loss_G: 8.6227
# Loss_D: 0.0117, Loss_G: 8.3774
# Loss_D: 0.0619, Loss_G: 7.0876
# Loss_D: 0.0850, Loss_G: 12.8790
# Loss_D: 0.0112, Loss_G: 13.2117
# Loss_D: 0.0219, Loss_G: 10.6120
# Loss_D: 0.0090, Loss_G: 7.2919
# Loss_D: 0.0579, Loss_G: 10.3220
# Loss_D: 0.0078, Loss_G: 10.1290
# Loss_D: 0.0187, Loss_G: 8.0303
# Loss_D: 0.0278, Loss_G: 6.7782
# Loss_D: 0.0767, Loss_G: 12.4584
# Loss_D: 0.0668, Loss_G: 12.0186
# Loss_D: 0.0476, Loss_G: 8.6959
# Loss_D: 0.0696, Loss_G: 6.1589
# Loss_D: 0.1733, Loss_G: 22.3521
# Loss_D: 0.1865, Loss_G: 22.6374
# Loss_D: 0.0187, Loss_G: 18.9285
# Loss_D: 0.0006, Loss_G: 13.1808
# Loss_D: 0.0028, Loss_G: 6.9633
# Loss_D: 0.3235, Loss_G: 31.1541
# Loss_D: 3.5328, Loss_G: 13.3246
# Loss_D: 0.0156, Loss_G: 1.2998
# Loss_D: 5.0919, Loss_G: 36.4652
# Loss_D: 9.7777, Loss_G: 29.7699
# Loss_D: 0.8687, Loss_G: 23.2634
# Loss_D: 0.0967, Loss_G: 13.7515
# Loss_D: 0.3018, Loss_G: 8.6369
# Loss_D: 1.8526, Loss_G: 25.0491
# Loss_D: 1.3176, Loss_G: 24.8344
# Loss_D: 1.1202, Loss_G: 18.9566
# Loss_D: 0.1141, Loss_G: 9.0150
# Loss_D: 3.2958, Loss_G: 28.4269
# Loss_D: 0.7594, Loss_G: 32.6234
# Loss_D: 1.0621, Loss_G: 31.8078
# Loss_D: 0.0628, Loss_G: 30.5212
# Loss_D: 0.0233, Loss_G: 28.4917
# Loss_D: 0.0089, Loss_G: 23.5383
# Loss_D: 0.0068, Loss_G: 6.4291
# Loss_D: 9.3142, Loss_G: 22.8355
# Loss_D: 1.0595, Loss_G: 24.6263
# Loss_D: 0.8117, Loss_G: 20.6217
# Loss_D: 0.2972, Loss_G: 14.3266
# Loss_D: 0.0344, Loss_G: 6.0010
# Loss_D: 4.9851, Loss_G: 21.6119
# Loss_D: 0.7402, Loss_G: 22.7600
# Loss_D: 1.3335, Loss_G: 12.7823
# Loss_D: 0.3742, Loss_G: 9.5083
# Loss_D: 0.1157, Loss_G: 7.8205
# Loss_D: 0.3423, Loss_G: 7.1501
# Loss_D: 0.4130, Loss_G: 13.2750
# Loss_D: 1.0280, Loss_G: 5.6488
# Loss_D: 0.6423, Loss_G: 13.1956
# Loss_D: 0.5606, Loss_G: 10.2557
# Loss_D: 0.2994, Loss_G: 4.7051
# Loss_D: 1.0982, Loss_G: 17.2537
# Loss_D: 4.0110, Loss_G: 3.6400
# Loss_D: 1.0689, Loss_G: 9.2525
# Loss_D: 0.1696, Loss_G: 9.7709
# Loss_D: 0.1820, Loss_G: 7.5104
# Loss_D: 0.2468, Loss_G: 5.2505
# Loss_D: 0.4422, Loss_G: 6.6005
# Loss_D: 0.1585, Loss_G: 6.0661
# Loss_D: 0.2253, Loss_G: 5.2370
# Loss_D: 0.1453, Loss_G: 5.2429
# Loss_D: 0.1771, Loss_G: 5.3150
# Loss_D: 0.2369, Loss_G: 5.2575
# Loss_D: 0.2105, Loss_G: 7.6137
# Loss_D: 0.2681, Loss_G: 5.0626
# Loss_D: 0.2404, Loss_G: 6.4140
# Loss_D: 0.1074, Loss_G: 5.9664
# Loss_D: 0.1176, Loss_G: 4.8503
# Loss_D: 0.1419, Loss_G: 5.5775
# Loss_D: 0.1380, Loss_G: 5.1204
# Loss_D: 0.1398, Loss_G: 5.0358
# Loss_D: 0.1372, Loss_G: 5.1466
# Loss_D: 0.2590, Loss_G: 3.3907
# Loss_D: 0.3229, Loss_G: 9.5299
# Loss_D: 0.2477, Loss_G: 8.1140
# Loss_D: 0.0793, Loss_G: 6.1648
# Loss_D: 0.0722, Loss_G: 4.9572
# Loss_D: 0.0992, Loss_G: 5.2104
# Loss_D: 0.1073, Loss_G: 5.9312
# Loss_D: 0.0963, Loss_G: 5.4863
# Loss_D: 0.1337, Loss_G: 5.0078
# Loss_D: 0.1212, Loss_G: 5.4162
# Loss_D: 0.1232, Loss_G: 6.3425
# Loss_D: 0.1949, Loss_G: 4.8305
# Loss_D: 0.0885, Loss_G: 5.0004
# Loss_D: 0.0851, Loss_G: 5.1969
# Loss_D: 0.0376, Loss_G: 5.3367
# Loss_D: 0.0507, Loss_G: 5.2512
# Loss_D: 0.0807, Loss_G: 4.9246
# Loss_D: 0.0527, Loss_G: 5.1908
# Loss_D: 0.1147, Loss_G: 4.0070
# Loss_D: 0.1127, Loss_G: 5.4499
# Loss_D: 0.1459, Loss_G: 4.8496
# Loss_D: 0.1208, Loss_G: 4.9760
# Loss_D: 0.1409, Loss_G: 4.5593
# Loss_D: 0.1003, Loss_G: 5.4139
# Loss_D: 0.0299, Loss_G: 5.8409
# Epoch: 1
# Loss_D: 0.2108, Loss_G: 5.3991
# Loss_D: 0.2433, Loss_G: 2.7749
# Loss_D: 0.4957, Loss_G: 12.0480
# Loss_D: 1.2739, Loss_G: 2.2551
# Loss_D: 0.8151, Loss_G: 8.9238
# Loss_D: 0.1565, Loss_G: 8.5975
# Loss_D: 0.1379, Loss_G: 5.9079
# Loss_D: 0.1174, Loss_G: 3.7107
# Loss_D: 0.3206, Loss_G: 7.4291
# Loss_D: 0.3258, Loss_G: 5.2081
# Loss_D: 0.0836, Loss_G: 4.2439
# Loss_D: 0.1128, Loss_G: 5.2151
# Loss_D: 0.1149, Loss_G: 5.4943
# Loss_D: 0.1712, Loss_G: 3.5925
# Loss_D: 0.1983, Loss_G: 6.4068
# Loss_D: 0.0821, Loss_G: 6.2108
# Loss_D: 0.0906, Loss_G: 3.8890
# Loss_D: 0.1228, Loss_G: 4.9576
# Loss_D: 0.0727, Loss_G: 5.2940
# Loss_D: 0.1008, Loss_G: 3.9185
# Loss_D: 0.0997, Loss_G: 4.1682
# Loss_D: 0.0943, Loss_G: 5.0013
# Loss_D: 0.1980, Loss_G: 3.3302
# Loss_D: 0.1699, Loss_G: 6.5679
# Loss_D: 0.1590, Loss_G: 3.2855
# Loss_D: 0.1506, Loss_G: 5.4033
# Loss_D: 0.0568, Loss_G: 5.6230
# Loss_D: 0.1070, Loss_G: 3.4647
# Loss_D: 0.0714, Loss_G: 4.6020
# Loss_D: 0.0878, Loss_G: 4.6788
# Loss_D: 0.0581, Loss_G: 4.5776
# Loss_D: 0.0806, Loss_G: 4.3294
# Loss_D: 0.0743, Loss_G: 4.0978
# Loss_D: 0.0580, Loss_G: 4.7128
# Loss_D: 0.0983, Loss_G: 4.7124
# Loss_D: 0.0627, Loss_G: 4.0331
# Loss_D: 0.0605, Loss_G: 4.7537
# Loss_D: 0.1270, Loss_G: 2.6958
# Loss_D: 0.1530, Loss_G: 6.8912
# Loss_D: 0.1156, Loss_G: 3.8016
# Loss_D: 0.0595, Loss_G: 3.7984
# Loss_D: 0.0642, Loss_G: 5.1310
# Loss_D: 0.0568, Loss_G: 5.0041
# Loss_D: 0.1477, Loss_G: 1.8282
# Loss_D: 0.3769, Loss_G: 11.3822
# Loss_D: 2.0726, Loss_G: 0.0189
# Loss_D: 5.7640, Loss_G: 11.0592
# Loss_D: 9.7080, Loss_G: 1.5644
# Loss_D: 1.3725, Loss_G: 0.7183
# Loss_D: 1.3424, Loss_G: 3.4855
# Loss_D: 1.3094, Loss_G: 2.2704
# Loss_D: 0.8041, Loss_G: 2.1384
# Loss_D: 0.6729, Loss_G: 2.6964
# Loss_D: 0.9295, Loss_G: 1.9731
# Loss_D: 0.7552, Loss_G: 2.4125
# Loss_D: 0.5977, Loss_G: 2.4306
# Loss_D: 0.4868, Loss_G: 2.6731
# Loss_D: 0.4787, Loss_G: 3.1512
# Loss_D: 0.5733, Loss_G: 1.9232
# Loss_D: 0.6113, Loss_G: 3.4296
# Loss_D: 0.3827, Loss_G: 3.1598
# Loss_D: 0.4969, Loss_G: 3.1964
# Loss_D: 0.6053, Loss_G: 2.8190
# Loss_D: 0.6723, Loss_G: 4.3532
# Loss_D: 0.6029, Loss_G: 2.1938
# Loss_D: 0.5577, Loss_G: 5.5725
# Loss_D: 0.3453, Loss_G: 4.1569
# Loss_D: 0.2947, Loss_G: 3.9949
# Loss_D: 0.4443, Loss_G: 4.2471
# Loss_D: 0.7385, Loss_G: 3.5167
# Loss_D: 0.4632, Loss_G: 2.8559
# Loss_D: 0.4613, Loss_G: 4.4775
# Loss_D: 0.4413, Loss_G: 2.6061
# Loss_D: 0.4463, Loss_G: 6.1514
# Loss_D: 0.3576, Loss_G: 3.8053
# Loss_D: 0.1653, Loss_G: 3.7611
# Loss_D: 0.3971, Loss_G: 6.1291
# Loss_D: 0.6510, Loss_G: 2.1801
# Loss_D: 0.5777, Loss_G: 5.6631
# Loss_D: 0.2652, Loss_G: 4.5977
# Loss_D: 0.2971, Loss_G: 3.1594
# Loss_D: 0.4821, Loss_G: 5.0784
# Loss_D: 0.5270, Loss_G: 2.1548
# Loss_D: 0.6815, Loss_G: 8.4320
# Loss_D: 1.5273, Loss_G: 1.8354
# Loss_D: 0.7142, Loss_G: 5.6667
# Loss_D: 0.0880, Loss_G: 6.1685
# Loss_D: 0.1740, Loss_G: 4.3188
# Loss_D: 0.5887, Loss_G: 5.2410
# Loss_D: 0.8293, Loss_G: 1.7374
# Loss_D: 0.9677, Loss_G: 7.8623
# Loss_D: 0.8233, Loss_G: 5.1178
# Loss_D: 0.0983, Loss_G: 3.1782
# Loss_D: 0.5472, Loss_G: 7.0611
# Loss_D: 0.4487, Loss_G: 4.5629
# Loss_D: 0.3434, Loss_G: 2.4269
# Loss_D: 0.6075, Loss_G: 6.4653
# Loss_D: 0.6717, Loss_G: 3.3412
# Loss_D: 0.3218, Loss_G: 3.6438
# Loss_D: 0.1733, Loss_G: 4.8497
# Loss_D: 0.2513, Loss_G: 3.4620
# Loss_D: 0.3579, Loss_G: 3.9038
# Loss_D: 0.1525, Loss_G: 4.6828
# Loss_D: 0.1406, Loss_G: 3.9914
# Loss_D: 0.2028, Loss_G: 3.3554
# Loss_D: 0.2826, Loss_G: 4.1792
# Loss_D: 0.1844, Loss_G: 4.1437
# Loss_D: 0.1694, Loss_G: 3.6967
# Loss_D: 0.1401, Loss_G: 4.5247
# Loss_D: 0.1245, Loss_G: 4.1504
# Loss_D: 0.2075, Loss_G: 2.7144
# Loss_D: 0.1889, Loss_G: 4.4763
# Loss_D: 0.2329, Loss_G: 2.9498
# Loss_D: 0.1736, Loss_G: 4.1764
# Loss_D: 0.1480, Loss_G: 3.8735
# Loss_D: 0.1523, Loss_G: 3.4729
# Loss_D: 0.2171, Loss_G: 3.5996
# Loss_D: 0.1797, Loss_G: 3.9299
# Loss_D: 0.1966, Loss_G: 2.9547
# Loss_D: 0.2550, Loss_G: 4.6467
# Loss_D: 0.1712, Loss_G: 4.2262
# Loss_D: 0.1825, Loss_G: 2.9358
# Loss_D: 0.2357, Loss_G: 5.6125
# Loss_D: 0.1771, Loss_G: 4.1127
# Loss_D: 0.0876, Loss_G: 3.6229
# Loss_D: 0.1275, Loss_G: 4.5225
# Loss_D: 0.2423, Loss_G: 3.2669
# Loss_D: 0.2416, Loss_G: 4.0780
# Loss_D: 0.2020, Loss_G: 3.8928
# Loss_D: 0.1630, Loss_G: 3.8367
# Loss_D: 0.1128, Loss_G: 4.3019
# Loss_D: 0.1560, Loss_G: 4.6252
# Loss_D: 0.1774, Loss_G: 2.6378
# Loss_D: 0.2487, Loss_G: 5.5133
# Loss_D: 0.1433, Loss_G: 4.3486
# Loss_D: 0.0915, Loss_G: 4.5877
# Loss_D: 0.0854, Loss_G: 4.2597
# Loss_D: 0.0701, Loss_G: 4.1068
# Loss_D: 0.0753, Loss_G: 4.1821
# Loss_D: 0.0928, Loss_G: 5.0037
# Loss_D: 0.1134, Loss_G: 3.9993
# Loss_D: 0.1399, Loss_G: 3.9640
# Loss_D: 0.1458, Loss_G: 4.1608
# Loss_D: 0.2022, Loss_G: 2.2576
# Loss_D: 0.3290, Loss_G: 9.5644
# Loss_D: 2.9436, Loss_G: 0.0075
# Loss_D: 7.0422, Loss_G: 7.9250
# Loss_D: 2.9059, Loss_G: 1.9104
# Loss_D: 1.6725, Loss_G: 3.7010
# Loss_D: 0.7925, Loss_G: 4.3929
# Loss_D: 1.0017, Loss_G: 1.2618
# Loss_D: 1.1271, Loss_G: 5.5513
# Loss_D: 1.3095, Loss_G: 1.6383
# Loss_D: 0.7472, Loss_G: 4.0852
# Loss_D: 0.5199, Loss_G: 3.0116
# Loss_D: 0.4856, Loss_G: 3.1061
# Loss_D: 0.7417, Loss_G: 1.4785
# Epoch: 2
# Loss_D: 1.0106, Loss_G: 4.7791
# Loss_D: 1.1552, Loss_G: 1.9138
# Loss_D: 0.5536, Loss_G: 2.5298
# Loss_D: 0.5309, Loss_G: 3.9770
# Loss_D: 0.3876, Loss_G: 3.2793
# Loss_D: 0.4081, Loss_G: 2.8421
# Loss_D: 0.5455, Loss_G: 3.2899
# Loss_D: 0.6329, Loss_G: 1.7385
# Loss_D: 0.7957, Loss_G: 4.7425
# Loss_D: 0.5639, Loss_G: 2.8947
# Loss_D: 0.3157, Loss_G: 2.9401
# Loss_D: 0.3177, Loss_G: 3.9865
# Loss_D: 0.3173, Loss_G: 3.3810
# Loss_D: 0.3818, Loss_G: 2.3242
# Loss_D: 0.4216, Loss_G: 3.3832
# Loss_D: 0.3803, Loss_G: 2.4966
# Loss_D: 0.4835, Loss_G: 2.7027
# Loss_D: 0.3711, Loss_G: 3.6056
# Loss_D: 0.4703, Loss_G: 2.0094
# Loss_D: 0.4544, Loss_G: 4.4022
# Loss_D: 0.3318, Loss_G: 3.0882
# Loss_D: 0.2990, Loss_G: 3.2924
# Loss_D: 0.3134, Loss_G: 2.7658
# Loss_D: 0.2538, Loss_G: 3.1037
# Loss_D: 0.3137, Loss_G: 2.4918
# Loss_D: 0.2483, Loss_G: 3.2276
# Loss_D: 0.2275, Loss_G: 3.1584
# Loss_D: 0.2579, Loss_G: 2.7684
# Loss_D: 0.3659, Loss_G: 3.8872
# Loss_D: 0.2333, Loss_G: 2.8562
# Loss_D: 0.2912, Loss_G: 2.8855
# Loss_D: 0.2405, Loss_G: 4.5406
# Loss_D: 0.2437, Loss_G: 2.6728
# Loss_D: 0.1915, Loss_G: 3.0569
# Loss_D: 0.2060, Loss_G: 3.4970
# Loss_D: 0.2510, Loss_G: 3.9970
# Loss_D: 0.2725, Loss_G: 2.1305
# Loss_D: 0.4232, Loss_G: 5.2658
# Loss_D: 0.7578, Loss_G: 0.5495
# Loss_D: 1.2956, Loss_G: 9.4669
# Loss_D: 2.6501, Loss_G: 1.4107
# Loss_D: 0.9534, Loss_G: 5.5515
# Loss_D: 1.4848, Loss_G: 0.5303
# Loss_D: 2.2897, Loss_G: 8.5766
# Loss_D: 3.4899, Loss_G: 2.6846
# Loss_D: 0.6718, Loss_G: 1.7229
# Loss_D: 1.4570, Loss_G: 6.1232
# Loss_D: 1.8106, Loss_G: 1.8216
# Loss_D: 1.0125, Loss_G: 2.4307
# Loss_D: 0.6566, Loss_G: 3.5793
# Loss_D: 0.6251, Loss_G: 2.2621
# Loss_D: 0.7345, Loss_G: 3.6438
# Loss_D: 0.6664, Loss_G: 2.1918
# Loss_D: 0.6245, Loss_G: 3.5427
# Loss_D: 0.3713, Loss_G: 3.8120
# Loss_D: 0.4233, Loss_G: 2.5267
# Loss_D: 0.6506, Loss_G: 4.3106
# Loss_D: 0.6244, Loss_G: 1.9381
# Loss_D: 0.5190, Loss_G: 3.8209
# Loss_D: 0.2138, Loss_G: 4.0922
# Loss_D: 0.1482, Loss_G: 3.6365
# Loss_D: 0.1350, Loss_G: 3.3195
# Loss_D: 0.1864, Loss_G: 3.2957
# Loss_D: 0.2216, Loss_G: 3.0570
# Loss_D: 0.3954, Loss_G: 2.9467
# Loss_D: 0.2437, Loss_G: 3.5065
# Loss_D: 0.2924, Loss_G: 2.2089
# Loss_D: 0.3689, Loss_G: 2.8844
# Loss_D: 0.2859, Loss_G: 2.5707
# Loss_D: 0.3117, Loss_G: 2.2942
# Loss_D: 0.3598, Loss_G: 3.8402
# Loss_D: 0.4676, Loss_G: 1.5339
# Loss_D: 0.3061, Loss_G: 3.5493
# Loss_D: 0.2667, Loss_G: 3.2044
# Loss_D: 0.2558, Loss_G: 2.4797
# Loss_D: 0.1971, Loss_G: 3.2009
# Loss_D: 0.2194, Loss_G: 3.3392
# Loss_D: 0.2599, Loss_G: 2.4497
# Loss_D: 0.2653, Loss_G: 3.5634
# Loss_D: 0.1759, Loss_G: 3.2417
# Loss_D: 0.1677, Loss_G: 2.8620
# Loss_D: 0.1946, Loss_G: 2.9432
# Loss_D: 0.2362, Loss_G: 3.9120
# Loss_D: 0.1861, Loss_G: 3.0181
# Loss_D: 0.2197, Loss_G: 2.5298
# Loss_D: 0.2406, Loss_G: 3.5654
# Loss_D: 0.2129, Loss_G: 2.8671
# Loss_D: 0.1312, Loss_G: 3.3825
# Loss_D: 0.2532, Loss_G: 3.6232
# Loss_D: 0.1802, Loss_G: 2.8543
# Loss_D: 0.2201, Loss_G: 3.7295
# Loss_D: 0.1193, Loss_G: 3.8857
# Loss_D: 0.2174, Loss_G: 1.9499
# Loss_D: 0.3025, Loss_G: 4.7482
# Loss_D: 0.6328, Loss_G: 0.3128
# Loss_D: 1.5642, Loss_G: 8.4820
# Loss_D: 2.1527, Loss_G: 1.5737
# Loss_D: 0.5228, Loss_G: 3.6018
# Loss_D: 0.2599, Loss_G: 3.0364
# Loss_D: 0.2299, Loss_G: 2.3827
# Loss_D: 0.3369, Loss_G: 3.7183
# Loss_D: 0.5128, Loss_G: 1.2482
# Loss_D: 0.7653, Loss_G: 5.7810
# Loss_D: 0.7715, Loss_G: 2.2450
# Loss_D: 0.3667, Loss_G: 2.9972
# Loss_D: 0.3080, Loss_G: 3.9080
# Loss_D: 0.3143, Loss_G: 2.5835
# Loss_D: 0.3038, Loss_G: 2.8977
# Loss_D: 0.2489, Loss_G: 3.8505
# Loss_D: 0.2610, Loss_G: 2.8867
# Loss_D: 0.2173, Loss_G: 3.1407
# Loss_D: 0.3046, Loss_G: 3.3236
# Loss_D: 0.2577, Loss_G: 3.7323
# Loss_D: 0.2664, Loss_G: 2.5791
# Loss_D: 0.2412, Loss_G: 3.9817
# Loss_D: 0.2233, Loss_G: 3.4905
# Loss_D: 0.1608, Loss_G: 3.3680
# Loss_D: 0.1452, Loss_G: 3.5868
# Loss_D: 0.0884, Loss_G: 3.9306
# Loss_D: 0.1420, Loss_G: 3.6776
# Loss_D: 0.1663, Loss_G: 3.6701
# Loss_D: 0.1184, Loss_G: 3.9405
# Loss_D: 0.1276, Loss_G: 3.4751
# Loss_D: 0.1532, Loss_G: 3.4778
# Loss_D: 0.1529, Loss_G: 4.1034
# Loss_D: 0.2450, Loss_G: 2.3200
# Loss_D: 0.2824, Loss_G: 4.0364
# Loss_D: 0.2688, Loss_G: 2.4146
# Loss_D: 0.3357, Loss_G: 5.8287
# Loss_D: 0.5292, Loss_G: 1.6486
# Loss_D: 0.3770, Loss_G: 4.3679
# Loss_D: 0.1967, Loss_G: 4.0224
# Loss_D: 0.2365, Loss_G: 2.6769
# Loss_D: 0.1711, Loss_G: 3.9612
# Loss_D: 0.1403, Loss_G: 4.0793
# Loss_D: 0.1673, Loss_G: 3.1894
# Loss_D: 0.2054, Loss_G: 3.7303
# Loss_D: 0.1977, Loss_G: 3.0468
# Loss_D: 0.1312, Loss_G: 4.1156
# Loss_D: 0.1551, Loss_G: 3.6332
# Loss_D: 0.1173, Loss_G: 3.6345
# Loss_D: 0.1789, Loss_G: 2.6816
# Loss_D: 0.1745, Loss_G: 4.2250
# Loss_D: 0.1592, Loss_G: 2.7881
# Loss_D: 0.1837, Loss_G: 4.0823
# Loss_D: 0.1524, Loss_G: 3.2579
# Loss_D: 0.1276, Loss_G: 3.0787
# Loss_D: 0.1196, Loss_G: 4.2148
# Loss_D: 0.1209, Loss_G: 3.4075
# Loss_D: 0.1143, Loss_G: 3.7597
# Loss_D: 0.1261, Loss_G: 2.7876
# Loss_D: 0.1731, Loss_G: 4.1569
# Loss_D: 0.1292, Loss_G: 3.3340
# Loss_D: 0.1130, Loss_G: 3.8996
# Loss_D: 0.1347, Loss_G: 3.1264
# Loss_D: 0.0894, Loss_G: 3.8717
# Loss_D: 0.2064, Loss_G: 2.1340
# Epoch: 3
# Loss_D: 0.1652, Loss_G: 4.7932
# Loss_D: 0.2750, Loss_G: 1.3257
# Loss_D: 0.6483, Loss_G: 9.4580
# Loss_D: 2.8229, Loss_G: 3.5907
# Loss_D: 1.2886, Loss_G: 0.0015
# Loss_D: 8.5425, Loss_G: 3.0633
# Loss_D: 0.8171, Loss_G: 3.4247
# Loss_D: 0.9278, Loss_G: 0.6962
# Loss_D: 1.2465, Loss_G: 3.3832
# Loss_D: 0.8212, Loss_G: 1.6878
# Loss_D: 0.6609, Loss_G: 2.4883
# Loss_D: 0.6382, Loss_G: 1.7733
# Loss_D: 0.5467, Loss_G: 2.8005
# Loss_D: 0.5967, Loss_G: 1.6016
# Loss_D: 0.5028, Loss_G: 2.5885
# Loss_D: 0.4790, Loss_G: 1.9354
# Loss_D: 0.4387, Loss_G: 2.5495
# Loss_D: 0.5573, Loss_G: 1.5388
# Loss_D: 0.4726, Loss_G: 3.1046
# Loss_D: 0.3782, Loss_G: 2.4454
# Loss_D: 0.3627, Loss_G: 1.6971
# Loss_D: 0.5327, Loss_G: 3.4857
# Loss_D: 0.4698, Loss_G: 1.8289
# Loss_D: 0.3711, Loss_G: 2.9645
# Loss_D: 0.4216, Loss_G: 2.2327
# Loss_D: 0.3279, Loss_G: 2.6736
# Loss_D: 0.3658, Loss_G: 1.9491
# Loss_D: 0.4314, Loss_G: 3.9307
# Loss_D: 0.5518, Loss_G: 1.0272
# Loss_D: 0.6999, Loss_G: 4.5220
# Loss_D: 0.6828, Loss_G: 1.5582
# Loss_D: 0.4922, Loss_G: 3.7111
# Loss_D: 0.2757, Loss_G: 3.2881
# Loss_D: 0.3782, Loss_G: 1.6173
# Loss_D: 0.4276, Loss_G: 3.6297
# Loss_D: 0.3799, Loss_G: 2.0972
# Loss_D: 0.3775, Loss_G: 3.5972
# Loss_D: 0.2575, Loss_G: 3.1165
# Loss_D: 0.2495, Loss_G: 2.4685
# Loss_D: 0.2194, Loss_G: 3.6912
# Loss_D: 0.2932, Loss_G: 2.4491
# Loss_D: 0.2764, Loss_G: 3.8314
# Loss_D: 0.3756, Loss_G: 1.5688
# Loss_D: 0.3843, Loss_G: 4.3510
# Loss_D: 0.3784, Loss_G: 2.1880
# Loss_D: 0.2723, Loss_G: 3.1315
# Loss_D: 0.2216, Loss_G: 3.8683
# Loss_D: 0.2466, Loss_G: 2.9630
# Loss_D: 0.2183, Loss_G: 2.1449
# Loss_D: 0.2118, Loss_G: 3.8901
# Loss_D: 0.3242, Loss_G: 1.7275
# Loss_D: 0.4794, Loss_G: 5.7057
# Loss_D: 0.6435, Loss_G: 1.3118
# Loss_D: 0.7486, Loss_G: 5.5274
# Loss_D: 0.9804, Loss_G: 0.5979
# Loss_D: 1.1751, Loss_G: 6.0088
# Loss_D: 0.6906, Loss_G: 2.6815
# Loss_D: 0.2729, Loss_G: 2.2703
# Loss_D: 0.3719, Loss_G: 4.5901
# Loss_D: 0.2635, Loss_G: 3.5038
# Loss_D: 0.2335, Loss_G: 1.9774
# Loss_D: 0.4382, Loss_G: 4.8583
# Loss_D: 0.3808, Loss_G: 2.7451
# Loss_D: 0.2111, Loss_G: 2.9641
# Loss_D: 0.2112, Loss_G: 3.1918
# Loss_D: 0.1699, Loss_G: 2.9897
# Loss_D: 0.1862, Loss_G: 3.3580
# Loss_D: 0.2034, Loss_G: 2.5994
# Loss_D: 0.2060, Loss_G: 3.7107
# Loss_D: 0.2025, Loss_G: 2.9189
# Loss_D: 0.1819, Loss_G: 2.9929
# Loss_D: 0.2230, Loss_G: 4.2713
# Loss_D: 0.3521, Loss_G: 1.3812
# Loss_D: 0.3866, Loss_G: 4.5787
# Loss_D: 0.2722, Loss_G: 3.0911
# Loss_D: 0.1609, Loss_G: 2.9088
# Loss_D: 0.1391, Loss_G: 3.4908
# Loss_D: 0.2395, Loss_G: 2.8978
# Loss_D: 0.1237, Loss_G: 3.5215
# Loss_D: 0.1769, Loss_G: 3.2319
# Loss_D: 0.1579, Loss_G: 2.7949
# Loss_D: 0.2099, Loss_G: 4.6509
# Loss_D: 0.4445, Loss_G: 1.0097
# Loss_D: 0.7884, Loss_G: 8.4843
# Loss_D: 4.0707, Loss_G: 0.7068
# Loss_D: 1.5210, Loss_G: 13.2594
# Loss_D: 8.0594, Loss_G: 0.1151
# Loss_D: 3.4015, Loss_G: 4.5477
# Loss_D: 1.6583, Loss_G: 2.1372
# Loss_D: 0.9496, Loss_G: 1.4987
# Loss_D: 1.0627, Loss_G: 3.5200
# Loss_D: 1.2051, Loss_G: 0.9813
# Loss_D: 1.3795, Loss_G: 3.4378
# Loss_D: 1.2784, Loss_G: 1.2577
# Loss_D: 0.9905, Loss_G: 3.0457
# Loss_D: 0.8870, Loss_G: 1.3384
# Loss_D: 0.6624, Loss_G: 2.3625
# Loss_D: 0.6094, Loss_G: 2.3095
# Loss_D: 0.7206, Loss_G: 1.1486
# Loss_D: 1.0533, Loss_G: 3.6834
# Loss_D: 0.7924, Loss_G: 1.9084
# Loss_D: 0.5230, Loss_G: 2.0472
# Loss_D: 0.5408, Loss_G: 3.0124
# Loss_D: 0.5854, Loss_G: 1.5675
# Loss_D: 0.5331, Loss_G: 2.4799
# Loss_D: 0.4826, Loss_G: 2.6197
# Loss_D: 0.4936, Loss_G: 1.6018
# Loss_D: 0.5239, Loss_G: 2.5921
# Loss_D: 0.5469, Loss_G: 2.0504
# Loss_D: 0.3846, Loss_G: 2.1548
# Loss_D: 0.3903, Loss_G: 2.5639
# Loss_D: 0.4016, Loss_G: 1.8627
# Loss_D: 0.4178, Loss_G: 3.1797
# Loss_D: 0.4387, Loss_G: 2.3769
# Loss_D: 0.3762, Loss_G: 2.1549
# Loss_D: 0.3594, Loss_G: 2.4859
# Loss_D: 0.4005, Loss_G: 2.3315
# Loss_D: 0.3726, Loss_G: 2.0922
# Loss_D: 0.4684, Loss_G: 3.4499
# Loss_D: 0.6540, Loss_G: 0.9109
# Loss_D: 0.7623, Loss_G: 4.0218
# Loss_D: 0.4059, Loss_G: 3.0175
# Loss_D: 0.4352, Loss_G: 1.3834
# Loss_D: 0.5485, Loss_G: 3.3661
# Loss_D: 0.4754, Loss_G: 2.1369
# Loss_D: 0.3292, Loss_G: 2.5836
# Loss_D: 0.2707, Loss_G: 2.9909
# Loss_D: 0.2953, Loss_G: 2.3591
# Loss_D: 0.2829, Loss_G: 2.4451
# Loss_D: 0.3905, Loss_G: 2.9118
# Loss_D: 0.2429, Loss_G: 2.5654
# Loss_D: 0.3035, Loss_G: 2.6666
# Loss_D: 0.2180, Loss_G: 2.9142
# Loss_D: 0.3231, Loss_G: 2.2588
# Loss_D: 0.2200, Loss_G: 2.9234
# Loss_D: 0.2684, Loss_G: 2.6997
# Loss_D: 0.4299, Loss_G: 1.5846
# Loss_D: 0.3750, Loss_G: 3.9162
# Loss_D: 0.3442, Loss_G: 2.1484
# Loss_D: 0.3367, Loss_G: 2.1543
# Loss_D: 0.3482, Loss_G: 3.6593
# Loss_D: 0.4239, Loss_G: 1.5278
# Loss_D: 0.5899, Loss_G: 4.2037
# Loss_D: 0.4329, Loss_G: 1.7806
# Loss_D: 0.3029, Loss_G: 3.0527
# Loss_D: 0.2705, Loss_G: 3.0372
# Loss_D: 0.2575, Loss_G: 3.0809
# Loss_D: 0.2765, Loss_G: 2.2428
# Loss_D: 0.3607, Loss_G: 3.5249
# Loss_D: 0.3024, Loss_G: 2.2483
# Loss_D: 0.3381, Loss_G: 3.2431
# Loss_D: 0.2920, Loss_G: 2.2485
# Loss_D: 0.2345, Loss_G: 2.3745
# Loss_D: 0.3748, Loss_G: 4.2542
# Loss_D: 0.5901, Loss_G: 0.7792
# Loss_D: 0.6785, Loss_G: 4.7808
# Loss_D: 0.9911, Loss_G: 1.0334
# Epoch: 4
# Loss_D: 1.1778, Loss_G: 7.8446
# Loss_D: 2.9901, Loss_G: 0.3722
# Loss_D: 2.5838, Loss_G: 5.0503
# Loss_D: 1.5213, Loss_G: 1.4523
# Loss_D: 0.5645, Loss_G: 2.1375
# Loss_D: 0.6225, Loss_G: 3.4616
# Loss_D: 0.6868, Loss_G: 1.7393
# Loss_D: 0.3914, Loss_G: 2.4719
# Loss_D: 0.3067, Loss_G: 3.0362
# Loss_D: 0.4578, Loss_G: 2.4215
# Loss_D: 0.4010, Loss_G: 1.7815
# Loss_D: 0.4257, Loss_G: 3.0467
# Loss_D: 0.4615, Loss_G: 1.9392
# Loss_D: 0.3910, Loss_G: 2.2851
# Loss_D: 0.3775, Loss_G: 2.8853
# Loss_D: 0.2712, Loss_G: 2.5488
# Loss_D: 0.3248, Loss_G: 2.0965
# Loss_D: 0.3323, Loss_G: 2.4210
# Loss_D: 0.3663, Loss_G: 2.8782
# Loss_D: 0.2470, Loss_G: 2.6758
# Loss_D: 0.2457, Loss_G: 2.1083
# Loss_D: 0.3845, Loss_G: 3.0781
# Loss_D: 0.2784, Loss_G: 2.7804
# Loss_D: 0.2536, Loss_G: 2.5397
# Loss_D: 0.2952, Loss_G: 2.6789
# Loss_D: 0.2080, Loss_G: 2.9642
# Loss_D: 0.2696, Loss_G: 2.1380
# Loss_D: 0.2646, Loss_G: 2.9238
# Loss_D: 0.2755, Loss_G: 3.2848
# Loss_D: 0.2255, Loss_G: 2.6953
# Loss_D: 0.2880, Loss_G: 2.1803
# Loss_D: 0.3372, Loss_G: 2.6674
# Loss_D: 0.2393, Loss_G: 3.1314
# Loss_D: 0.2674, Loss_G: 2.8401
# Loss_D: 0.2861, Loss_G: 2.1610
# Loss_D: 0.2523, Loss_G: 3.0361
# Loss_D: 0.1726, Loss_G: 3.3603
# Loss_D: 0.2818, Loss_G: 2.4949
# Loss_D: 0.2979, Loss_G: 2.4969
# Loss_D: 0.2894, Loss_G: 2.9726
# Loss_D: 0.3392, Loss_G: 1.5346
# Loss_D: 0.5160, Loss_G: 5.4283
# Loss_D: 0.8607, Loss_G: 0.7301
# Loss_D: 0.9724, Loss_G: 5.8053
# Loss_D: 0.9314, Loss_G: 1.1804
# Loss_D: 0.4108, Loss_G: 2.9236
# Loss_D: 0.3830, Loss_G: 3.4325
# Loss_D: 0.6736, Loss_G: 0.8733
# Loss_D: 0.7866, Loss_G: 5.0309
# Loss_D: 0.7268, Loss_G: 1.5399
# Loss_D: 0.5171, Loss_G: 3.6379
# Loss_D: 0.3571, Loss_G: 2.5854
# Loss_D: 0.2813, Loss_G: 2.4777
# Loss_D: 0.2415, Loss_G: 3.3003
# Loss_D: 0.3044, Loss_G: 2.2625
# Loss_D: 0.2475, Loss_G: 3.1855
# Loss_D: 0.4133, Loss_G: 1.5905
# Loss_D: 0.2549, Loss_G: 3.3431
# Loss_D: 0.3391, Loss_G: 2.6653
# Loss_D: 0.2205, Loss_G: 2.3179
# Loss_D: 0.2317, Loss_G: 3.2668
# Loss_D: 0.2107, Loss_G: 2.9142
# Loss_D: 0.2055, Loss_G: 2.4095
# Loss_D: 0.2070, Loss_G: 3.5727
# Loss_D: 0.2708, Loss_G: 2.3218
# Loss_D: 0.2853, Loss_G: 2.8756
# Loss_D: 0.2032, Loss_G: 3.5510
# Loss_D: 0.3870, Loss_G: 1.1497
# Loss_D: 0.4817, Loss_G: 4.9053
# Loss_D: 0.8448, Loss_G: 0.6436
# Loss_D: 1.0918, Loss_G: 9.6522
# Loss_D: 5.6403, Loss_G: 0.2112
# Loss_D: 2.3544, Loss_G: 4.2116
# Loss_D: 0.9234, Loss_G: 1.8333
# Loss_D: 0.5549, Loss_G: 1.6121
# Loss_D: 0.6071, Loss_G: 3.2700
# Loss_D: 0.7254, Loss_G: 1.1172
# Loss_D: 0.8358, Loss_G: 3.4761
# Loss_D: 0.7600, Loss_G: 1.1886
# Loss_D: 0.6598, Loss_G: 3.0758
# Loss_D: 0.6447, Loss_G: 1.5241
# Loss_D: 0.6062, Loss_G: 3.3624
# Loss_D: 0.6737, Loss_G: 1.5276
# Loss_D: 0.4533, Loss_G: 3.0795
# Loss_D: 0.4053, Loss_G: 2.7495
# Loss_D: 0.3935, Loss_G: 2.0993
# Loss_D: 0.3054, Loss_G: 2.4620
# Loss_D: 0.3765, Loss_G: 2.2554
# Loss_D: 0.4428, Loss_G: 3.0607
# Loss_D: 0.4232, Loss_G: 2.0905
# Loss_D: 0.4300, Loss_G: 1.9912
# Loss_D: 0.3200, Loss_G: 3.2776
# Loss_D: 0.3180, Loss_G: 2.2238
# Loss_D: 0.3902, Loss_G: 2.5049
# Loss_D: 0.3829, Loss_G: 2.4402
# Loss_D: 0.3142, Loss_G: 2.8622
# Loss_D: 0.3583, Loss_G: 1.7032
# Loss_D: 0.3129, Loss_G: 3.1823
# Loss_D: 0.4096, Loss_G: 2.2458
# Loss_D: 0.3682, Loss_G: 2.0923
# Loss_D: 0.2196, Loss_G: 3.0760
# Loss_D: 0.3588, Loss_G: 2.5642
# Loss_D: 0.3169, Loss_G: 2.1886
# Loss_D: 0.2411, Loss_G: 3.0034
# Loss_D: 0.2526, Loss_G: 2.5549
# Loss_D: 0.4181, Loss_G: 2.3434
# Loss_D: 0.2583, Loss_G: 2.7125
# Loss_D: 0.2553, Loss_G: 3.2956
# Loss_D: 0.3321, Loss_G: 1.6316
# Loss_D: 0.3959, Loss_G: 4.7394
# Loss_D: 0.6588, Loss_G: 0.7587
# Loss_D: 1.4220, Loss_G: 7.7481
# Loss_D: 3.6428, Loss_G: 0.6520
# Loss_D: 1.2957, Loss_G: 3.5846
# Loss_D: 0.5367, Loss_G: 2.2086
# Loss_D: 0.4841, Loss_G: 2.1002
# Loss_D: 0.3699, Loss_G: 2.6882
# Loss_D: 0.3996, Loss_G: 2.4251
# Loss_D: 0.3865, Loss_G: 2.6959
# Loss_D: 0.4173, Loss_G: 2.2309
# Loss_D: 0.3385, Loss_G: 2.7850
# Loss_D: 0.2985, Loss_G: 2.3123
# Loss_D: 0.2757, Loss_G: 2.5057
# Loss_D: 0.2545, Loss_G: 2.8905
# Loss_D: 0.2808, Loss_G: 2.6835
# Loss_D: 0.2550, Loss_G: 2.3679
# Loss_D: 0.3023, Loss_G: 2.9814
# Loss_D: 0.3708, Loss_G: 2.4757
# Loss_D: 0.2639, Loss_G: 2.0316
# Loss_D: 0.3891, Loss_G: 3.1535
# Loss_D: 0.3508, Loss_G: 2.0070
# Loss_D: 0.3224, Loss_G: 3.5741
# Loss_D: 0.3081, Loss_G: 2.5038
# Loss_D: 0.3510, Loss_G: 2.5624
# Loss_D: 0.2092, Loss_G: 3.2936
# Loss_D: 0.2143, Loss_G: 2.6596
# Loss_D: 0.3300, Loss_G: 2.4260
# Loss_D: 0.2525, Loss_G: 2.4889
# Loss_D: 0.2345, Loss_G: 3.2881
# Loss_D: 0.2442, Loss_G: 3.0007
# Loss_D: 0.3384, Loss_G: 1.4096
# Loss_D: 0.4443, Loss_G: 4.5937
# Loss_D: 0.6467, Loss_G: 0.9999
# Loss_D: 0.7412, Loss_G: 7.5705
# Loss_D: 3.0228, Loss_G: 0.6222
# Loss_D: 1.6571, Loss_G: 9.9073
# Loss_D: 6.9714, Loss_G: 1.3602
# Loss_D: 1.1001, Loss_G: 0.8103
# Loss_D: 1.3373, Loss_G: 3.5589
# Loss_D: 1.8472, Loss_G: 0.4925
# Loss_D: 1.3467, Loss_G: 2.5341
# Loss_D: 0.8739, Loss_G: 1.7864
# Loss_D: 0.9114, Loss_G: 1.8287
# Loss_D: 0.8994, Loss_G: 1.5832
# Loss_D: 1.0499, Loss_G: 1.4568
# Loss_D: 0.9323, Loss_G: 1.2734
# Loss_D: 0.6649, Loss_G: 3.6662
# Epoch: 5
# Loss_D: 0.9157, Loss_G: 1.1438
# Loss_D: 0.8574, Loss_G: 2.7817
# Loss_D: 1.0456, Loss_G: 0.8727
# Loss_D: 1.2983, Loss_G: 3.5043
# Loss_D: 1.5631, Loss_G: 1.1179
# Loss_D: 1.0582, Loss_G: 2.0156
# Loss_D: 0.9961, Loss_G: 1.8037
# Loss_D: 0.7576, Loss_G: 1.5794
# Loss_D: 0.6723, Loss_G: 1.8382
# Loss_D: 0.7578, Loss_G: 2.0170
# Loss_D: 0.7626, Loss_G: 1.7819
# Loss_D: 0.6984, Loss_G: 1.4524
# Loss_D: 0.5945, Loss_G: 2.3600
# Loss_D: 0.6133, Loss_G: 1.6655
# Loss_D: 0.4284, Loss_G: 2.4323
# Loss_D: 0.6953, Loss_G: 1.4599
# Loss_D: 0.6420, Loss_G: 2.8206
# Loss_D: 0.7129, Loss_G: 0.9464
# Loss_D: 0.8671, Loss_G: 3.6741
# Loss_D: 0.7939, Loss_G: 1.1300
# Loss_D: 0.8995, Loss_G: 3.3325
# Loss_D: 0.7150, Loss_G: 1.4811
# Loss_D: 0.5722, Loss_G: 2.2044
# Loss_D: 0.5025, Loss_G: 2.1112
# Loss_D: 0.4419, Loss_G: 2.5041
# Loss_D: 0.6615, Loss_G: 0.9768
# Loss_D: 0.8686, Loss_G: 4.1747
# Loss_D: 1.2002, Loss_G: 0.7528
# Loss_D: 1.0922, Loss_G: 3.6452
# Loss_D: 0.6922, Loss_G: 2.0732
# Loss_D: 0.4765, Loss_G: 2.2826
# Loss_D: 0.3947, Loss_G: 2.6878
# Loss_D: 0.5326, Loss_G: 1.5222
# Loss_D: 0.4618, Loss_G: 2.5458
# Loss_D: 0.5977, Loss_G: 1.7707
# Loss_D: 0.4693, Loss_G: 2.4884
# Loss_D: 0.4877, Loss_G: 2.1849
# Loss_D: 0.4856, Loss_G: 1.5581
# Loss_D: 0.5130, Loss_G: 2.9615
# Loss_D: 0.5698, Loss_G: 1.4363
# Loss_D: 0.5215, Loss_G: 3.4041
# Loss_D: 0.6804, Loss_G: 1.0600
# Loss_D: 0.7171, Loss_G: 3.3229
# Loss_D: 0.6547, Loss_G: 1.3342
# Loss_D: 0.4428, Loss_G: 3.1137
# Loss_D: 0.6010, Loss_G: 1.2449
# Loss_D: 0.5098, Loss_G: 3.5986
# Loss_D: 0.4532, Loss_G: 2.0163
# Loss_D: 0.4271, Loss_G: 1.9335
# Loss_D: 0.4093, Loss_G: 2.7905
# Loss_D: 0.3896, Loss_G: 2.1763
# Loss_D: 0.4019, Loss_G: 2.2379
# Loss_D: 0.4360, Loss_G: 1.8926
# Loss_D: 0.4626, Loss_G: 3.0649
# Loss_D: 0.6403, Loss_G: 0.6241
# Loss_D: 0.9875, Loss_G: 4.8576
# Loss_D: 0.8998, Loss_G: 1.5254
# Loss_D: 0.4795, Loss_G: 1.9104
# Loss_D: 0.5185, Loss_G: 3.8830
# Loss_D: 0.5842, Loss_G: 1.4825
# Loss_D: 0.5217, Loss_G: 2.9708
# Loss_D: 0.3737, Loss_G: 2.7364
# Loss_D: 0.4631, Loss_G: 2.4274
# Loss_D: 0.4233, Loss_G: 1.4867
# Loss_D: 0.4384, Loss_G: 3.5725
# Loss_D: 0.5179, Loss_G: 1.2860
# Loss_D: 0.5342, Loss_G: 3.6601
# Loss_D: 0.4606, Loss_G: 2.0448
# Loss_D: 0.3843, Loss_G: 2.7819
# Loss_D: 0.3516, Loss_G: 2.7446
# Loss_D: 0.2947, Loss_G: 2.4501
# Loss_D: 0.3619, Loss_G: 2.1740
# Loss_D: 0.3108, Loss_G: 2.6314
# Loss_D: 0.3239, Loss_G: 2.4665
# Loss_D: 0.3308, Loss_G: 1.9080
# Loss_D: 0.4740, Loss_G: 4.3563
# Loss_D: 0.6280, Loss_G: 0.9800
# Loss_D: 0.8464, Loss_G: 5.0947
# Loss_D: 1.1272, Loss_G: 0.8555
# Loss_D: 0.9564, Loss_G: 5.3733
# Loss_D: 0.9685, Loss_G: 0.9187
# Loss_D: 0.9163, Loss_G: 3.6516
# Loss_D: 0.7552, Loss_G: 1.4693
# Loss_D: 0.5916, Loss_G: 3.1860
# Loss_D: 0.4980, Loss_G: 1.9816
# Loss_D: 0.3729, Loss_G: 2.8542
# Loss_D: 0.3855, Loss_G: 2.2295
# Loss_D: 0.3777, Loss_G: 2.5215
# Loss_D: 0.3596, Loss_G: 2.3667
# Loss_D: 0.3378, Loss_G: 1.8834
# Loss_D: 0.5020, Loss_G: 4.3474
# Loss_D: 0.8891, Loss_G: 0.4824
# Loss_D: 0.8253, Loss_G: 4.0829
# Loss_D: 0.4686, Loss_G: 2.9792
# Loss_D: 0.3915, Loss_G: 1.8726
# Loss_D: 0.3274, Loss_G: 2.6452
# Loss_D: 0.2959, Loss_G: 3.1167
# Loss_D: 0.4995, Loss_G: 1.4822
# Loss_D: 0.4249, Loss_G: 3.5914
# Loss_D: 0.4210, Loss_G: 2.0105
# Loss_D: 0.3457, Loss_G: 2.4313
# Loss_D: 0.2825, Loss_G: 3.8562
# Loss_D: 0.4690, Loss_G: 1.3683
# Loss_D: 0.4119, Loss_G: 3.0890
# Loss_D: 0.3383, Loss_G: 2.2239
# Loss_D: 0.2441, Loss_G: 2.8272
# Loss_D: 0.3052, Loss_G: 3.2562
# Loss_D: 0.3882, Loss_G: 1.7257
# Loss_D: 0.3625, Loss_G: 3.6143
# Loss_D: 0.2600, Loss_G: 2.6532
# Loss_D: 0.3298, Loss_G: 2.1225
# Loss_D: 0.3213, Loss_G: 3.0761
# Loss_D: 0.2301, Loss_G: 2.6445
# Loss_D: 0.3072, Loss_G: 2.2427
# Loss_D: 0.3832, Loss_G: 3.2080
# Loss_D: 0.3429, Loss_G: 1.9572
# Loss_D: 0.3338, Loss_G: 3.7367
# Loss_D: 0.4800, Loss_G: 1.0449
# Loss_D: 0.7919, Loss_G: 6.1828
# Loss_D: 1.2996, Loss_G: 1.6544
# Loss_D: 0.7317, Loss_G: 6.4975
# Loss_D: 2.5750, Loss_G: 0.0080
# Loss_D: 4.5140, Loss_G: 5.0723
# Loss_D: 0.4635, Loss_G: 4.6477
# Loss_D: 1.1431, Loss_G: 0.3944
# Loss_D: 2.1085, Loss_G: 4.2236
# Loss_D: 1.1798, Loss_G: 1.7615
# Loss_D: 0.6151, Loss_G: 2.0737
# Loss_D: 0.6133, Loss_G: 2.3201
# Loss_D: 0.7328, Loss_G: 1.7063
# Loss_D: 0.6021, Loss_G: 2.5631
# Loss_D: 0.5482, Loss_G: 2.1049
# Loss_D: 0.4595, Loss_G: 2.0274
# Loss_D: 0.6013, Loss_G: 1.9560
# Loss_D: 0.6376, Loss_G: 1.9467
# Loss_D: 0.5110, Loss_G: 2.5786
# Loss_D: 0.6109, Loss_G: 1.2088
# Loss_D: 0.8061, Loss_G: 3.0677
# Loss_D: 0.4678, Loss_G: 2.3759
# Loss_D: 0.5179, Loss_G: 1.2174
# Loss_D: 0.8855, Loss_G: 4.3399
# Loss_D: 1.0272, Loss_G: 1.1576
# Loss_D: 0.5850, Loss_G: 1.9545
# Loss_D: 0.4489, Loss_G: 3.4539
# Loss_D: 0.5535, Loss_G: 1.9225
# Loss_D: 0.4599, Loss_G: 1.9480
# Loss_D: 0.4497, Loss_G: 2.8804
# Loss_D: 0.6135, Loss_G: 1.4749
# Loss_D: 0.4166, Loss_G: 2.6019
# Loss_D: 0.4029, Loss_G: 2.6470
# Loss_D: 0.4308, Loss_G: 1.7685
# Loss_D: 0.3634, Loss_G: 3.2198
# Loss_D: 0.6016, Loss_G: 1.3063
# Loss_D: 0.4198, Loss_G: 2.9771
# Loss_D: 0.3806, Loss_G: 2.4058
# Loss_D: 0.4687, Loss_G: 2.6566
# Loss_D: 0.3198, Loss_G: 3.1662
# Epoch: 6
# Loss_D: 0.3378, Loss_G: 1.7471
# Loss_D: 0.3701, Loss_G: 2.7932
# Loss_D: 0.4259, Loss_G: 2.7008
# Loss_D: 0.4314, Loss_G: 1.8762
# Loss_D: 0.2843, Loss_G: 3.0670
# Loss_D: 0.3194, Loss_G: 2.3379
# Loss_D: 0.2939, Loss_G: 2.9498
# Loss_D: 0.2802, Loss_G: 2.9045
# Loss_D: 0.4035, Loss_G: 1.4512
# Loss_D: 0.4873, Loss_G: 2.5003
# Loss_D: 0.3091, Loss_G: 3.1038
# Loss_D: 0.2840, Loss_G: 2.2638
# Loss_D: 0.3048, Loss_G: 2.2928
# Loss_D: 0.2990, Loss_G: 3.3945
# Loss_D: 0.2732, Loss_G: 2.6168
# Loss_D: 0.3482, Loss_G: 1.8176
# Loss_D: 0.3725, Loss_G: 4.1607
# Loss_D: 0.5922, Loss_G: 1.0454
# Loss_D: 0.9904, Loss_G: 5.2433
# Loss_D: 1.2431, Loss_G: 1.5279
# Loss_D: 0.4301, Loss_G: 2.7239
# Loss_D: 0.4452, Loss_G: 1.8808
# Loss_D: 0.5572, Loss_G: 3.4015
# Loss_D: 0.7516, Loss_G: 0.4291
# Loss_D: 1.4638, Loss_G: 6.3765
# Loss_D: 1.7570, Loss_G: 1.0264
# Loss_D: 1.2545, Loss_G: 3.2908
# Loss_D: 0.7783, Loss_G: 1.9563
# Loss_D: 0.3712, Loss_G: 1.8216
# Loss_D: 0.6068, Loss_G: 3.8069
# Loss_D: 0.7454, Loss_G: 1.1249
# Loss_D: 1.0318, Loss_G: 4.3187
# Loss_D: 0.7715, Loss_G: 2.1840
# Loss_D: 0.4343, Loss_G: 1.7513
# Loss_D: 0.5678, Loss_G: 3.1378
# Loss_D: 0.5183, Loss_G: 1.8842
# Loss_D: 0.4416, Loss_G: 2.6704
# Loss_D: 0.3398, Loss_G: 2.3487
# Loss_D: 0.3829, Loss_G: 2.5945
# Loss_D: 0.4966, Loss_G: 1.7303
# Loss_D: 0.3059, Loss_G: 2.4074
# Loss_D: 0.3767, Loss_G: 3.1359
# Loss_D: 0.3767, Loss_G: 1.9944
# Loss_D: 0.3471, Loss_G: 3.1323
# Loss_D: 0.2756, Loss_G: 3.0212
# Loss_D: 0.4420, Loss_G: 1.6574
# Loss_D: 0.3782, Loss_G: 2.8556
# Loss_D: 0.3026, Loss_G: 2.4984
# Loss_D: 0.3331, Loss_G: 2.3775
# Loss_D: 0.2862, Loss_G: 2.7706
# Loss_D: 0.2926, Loss_G: 2.7702
# Loss_D: 0.5075, Loss_G: 1.2181
# Loss_D: 0.6039, Loss_G: 5.1259
# Loss_D: 0.5525, Loss_G: 2.3719
# Loss_D: 0.4327, Loss_G: 2.1566
# Loss_D: 0.3573, Loss_G: 3.2682
# Loss_D: 0.3231, Loss_G: 2.3362
# Loss_D: 0.2486, Loss_G: 2.6947
# Loss_D: 0.3297, Loss_G: 2.7310
# Loss_D: 0.3634, Loss_G: 1.8883
# Loss_D: 0.3095, Loss_G: 3.4368
# Loss_D: 0.3056, Loss_G: 2.3734
# Loss_D: 0.3211, Loss_G: 3.1511
# Loss_D: 0.2633, Loss_G: 2.6689
# Loss_D: 0.2235, Loss_G: 2.7573
# Loss_D: 0.3212, Loss_G: 2.4235
# Loss_D: 0.2690, Loss_G: 3.3693
# Loss_D: 0.2748, Loss_G: 2.1888
# Loss_D: 0.2943, Loss_G: 2.4054
# Loss_D: 0.2719, Loss_G: 3.8216
# Loss_D: 0.4464, Loss_G: 0.8507
# Loss_D: 0.9855, Loss_G: 8.1202
# Loss_D: 3.5622, Loss_G: 2.0599
# Loss_D: 0.7316, Loss_G: 4.6554
# Loss_D: 1.6771, Loss_G: 0.0099
# Loss_D: 5.9765, Loss_G: 4.2834
# Loss_D: 1.3683, Loss_G: 1.3511
# Loss_D: 1.0312, Loss_G: 1.8554
# Loss_D: 0.8511, Loss_G: 2.6163
# Loss_D: 1.0108, Loss_G: 1.3165
# Loss_D: 1.1843, Loss_G: 2.4150
# Loss_D: 1.1196, Loss_G: 0.7242
# Loss_D: 1.5678, Loss_G: 4.4577
# Loss_D: 2.0827, Loss_G: 0.5481
# Loss_D: 1.6490, Loss_G: 3.6152
# Loss_D: 1.2911, Loss_G: 1.1238
# Loss_D: 0.9551, Loss_G: 1.7486
# Loss_D: 0.8094, Loss_G: 2.5858
# Loss_D: 1.0074, Loss_G: 1.1868
# Loss_D: 0.5923, Loss_G: 2.3262
# Loss_D: 0.7006, Loss_G: 1.8229
# Loss_D: 0.6906, Loss_G: 2.7771
# Loss_D: 1.1073, Loss_G: 0.5096
# Loss_D: 1.3821, Loss_G: 3.0050
# Loss_D: 0.9088, Loss_G: 1.6932
# Loss_D: 0.8537, Loss_G: 1.8031
# Loss_D: 0.6144, Loss_G: 2.3311
# Loss_D: 0.8278, Loss_G: 1.0078
# Loss_D: 1.0156, Loss_G: 3.3794
# Loss_D: 0.8568, Loss_G: 2.1169
# Loss_D: 0.6384, Loss_G: 1.7029
# Loss_D: 0.5585, Loss_G: 1.9537
# Loss_D: 0.4577, Loss_G: 1.9751
# Loss_D: 0.6422, Loss_G: 2.5005
# Loss_D: 0.6228, Loss_G: 1.6016
# Loss_D: 0.6978, Loss_G: 2.3140
# Loss_D: 0.6489, Loss_G: 1.7067
# Loss_D: 0.4517, Loss_G: 2.2677
# Loss_D: 0.5448, Loss_G: 1.5924
# Loss_D: 0.5443, Loss_G: 3.0392
# Loss_D: 0.6784, Loss_G: 1.2802
# Loss_D: 0.7860, Loss_G: 3.0891
# Loss_D: 0.8364, Loss_G: 1.0695
# Loss_D: 0.7944, Loss_G: 3.3520
# Loss_D: 0.6056, Loss_G: 2.1577
# Loss_D: 0.4722, Loss_G: 1.3801
# Loss_D: 0.7236, Loss_G: 3.3740
# Loss_D: 0.7403, Loss_G: 1.3198
# Loss_D: 0.4466, Loss_G: 2.2597
# Loss_D: 0.4466, Loss_G: 2.2729
# Loss_D: 0.5334, Loss_G: 2.2323
# Loss_D: 0.4612, Loss_G: 1.6453
# Loss_D: 0.4472, Loss_G: 2.3959
# Loss_D: 0.5384, Loss_G: 2.0842
# Loss_D: 0.4761, Loss_G: 2.0312
# Loss_D: 0.3857, Loss_G: 2.4768
# Loss_D: 0.5856, Loss_G: 1.4472
# Loss_D: 0.5885, Loss_G: 3.4650
# Loss_D: 0.5751, Loss_G: 1.7805
# Loss_D: 0.4351, Loss_G: 1.9039
# Loss_D: 0.4167, Loss_G: 2.5251
# Loss_D: 0.4594, Loss_G: 2.0778
# Loss_D: 0.3969, Loss_G: 2.3096
# Loss_D: 0.3727, Loss_G: 2.4577
# Loss_D: 0.3361, Loss_G: 2.8736
# Loss_D: 0.3346, Loss_G: 2.0104
# Loss_D: 0.3985, Loss_G: 2.8085
# Loss_D: 0.4965, Loss_G: 1.6994
# Loss_D: 0.4446, Loss_G: 3.3603
# Loss_D: 0.5372, Loss_G: 1.2093
# Loss_D: 0.6211, Loss_G: 3.8907
# Loss_D: 0.7577, Loss_G: 0.9325
# Loss_D: 0.8497, Loss_G: 3.8540
# Loss_D: 0.6855, Loss_G: 1.4087
# Loss_D: 0.7706, Loss_G: 3.8848
# Loss_D: 0.6002, Loss_G: 1.6725
# Loss_D: 0.5595, Loss_G: 2.8637
# Loss_D: 0.3536, Loss_G: 2.7283
# Loss_D: 0.4611, Loss_G: 1.4451
# Loss_D: 0.5926, Loss_G: 3.9205
# Loss_D: 0.6857, Loss_G: 1.4782
# Loss_D: 0.7043, Loss_G: 3.4232
# Loss_D: 0.5246, Loss_G: 2.0412
# Loss_D: 0.4213, Loss_G: 1.6772
# Loss_D: 0.4378, Loss_G: 2.5893
# Loss_D: 0.3699, Loss_G: 3.1654
# Loss_D: 0.5510, Loss_G: 1.4701
# Epoch: 7
# Loss_D: 0.4932, Loss_G: 3.1229
# Loss_D: 0.5045, Loss_G: 2.8231
# Loss_D: 0.4063, Loss_G: 2.1602
# Loss_D: 0.4165, Loss_G: 2.9085
# Loss_D: 0.3581, Loss_G: 2.0663
# Loss_D: 0.5463, Loss_G: 3.5209
# Loss_D: 0.5481, Loss_G: 1.3817
# Loss_D: 0.5040, Loss_G: 3.3946
# Loss_D: 0.2979, Loss_G: 3.0664
# Loss_D: 0.4025, Loss_G: 1.6210
# Loss_D: 0.4672, Loss_G: 3.3356
# Loss_D: 0.5343, Loss_G: 1.4658
# Loss_D: 0.5631, Loss_G: 4.0091
# Loss_D: 0.4983, Loss_G: 2.1711
# Loss_D: 0.4834, Loss_G: 2.8021
# Loss_D: 0.3584, Loss_G: 2.3348
# Loss_D: 0.3632, Loss_G: 3.0486
# Loss_D: 0.4261, Loss_G: 1.5770
# Loss_D: 0.5700, Loss_G: 4.1083
# Loss_D: 0.5108, Loss_G: 1.9943
# Loss_D: 0.2763, Loss_G: 2.1622
# Loss_D: 0.4472, Loss_G: 3.9794
# Loss_D: 0.6453, Loss_G: 1.1358
# Loss_D: 0.5332, Loss_G: 3.7382
# Loss_D: 0.5239, Loss_G: 2.0419
# Loss_D: 0.2602, Loss_G: 2.7078
# Loss_D: 0.2594, Loss_G: 2.8236
# Loss_D: 0.3899, Loss_G: 2.9491
# Loss_D: 0.3120, Loss_G: 2.2285
# Loss_D: 0.3513, Loss_G: 3.7428
# Loss_D: 0.5422, Loss_G: 1.0588
# Loss_D: 0.7423, Loss_G: 4.7833
# Loss_D: 0.8415, Loss_G: 1.7151
# Loss_D: 0.6355, Loss_G: 3.9640
# Loss_D: 0.5494, Loss_G: 1.2262
# Loss_D: 0.5541, Loss_G: 4.1782
# Loss_D: 0.4354, Loss_G: 2.2905
# Loss_D: 0.4003, Loss_G: 2.5820
# Loss_D: 0.2957, Loss_G: 2.9223
# Loss_D: 0.3977, Loss_G: 2.3207
# Loss_D: 0.3048, Loss_G: 2.4459
# Loss_D: 0.3212, Loss_G: 2.5201
# Loss_D: 0.4464, Loss_G: 1.5613
# Loss_D: 0.5076, Loss_G: 4.3884
# Loss_D: 0.4707, Loss_G: 2.3167
# Loss_D: 0.3958, Loss_G: 2.9647
# Loss_D: 0.3735, Loss_G: 2.3212
# Loss_D: 0.2992, Loss_G: 2.8971
# Loss_D: 0.3953, Loss_G: 1.8654
# Loss_D: 0.4505, Loss_G: 4.1354
# Loss_D: 0.3676, Loss_G: 2.6668
# Loss_D: 0.3214, Loss_G: 1.9350
# Loss_D: 0.4632, Loss_G: 4.1472
# Loss_D: 0.6405, Loss_G: 1.0036
# Loss_D: 0.8270, Loss_G: 5.0404
# Loss_D: 0.8186, Loss_G: 1.4534
# Loss_D: 0.7293, Loss_G: 4.7467
# Loss_D: 0.9253, Loss_G: 1.0850
# Loss_D: 1.0590, Loss_G: 6.8050
# Loss_D: 2.3246, Loss_G: 0.1987
# Loss_D: 1.7044, Loss_G: 5.8041
# Loss_D: 1.6880, Loss_G: 0.6080
# Loss_D: 1.8419, Loss_G: 4.0140
# Loss_D: 1.3113, Loss_G: 1.1479
# Loss_D: 0.7341, Loss_G: 2.0600
# Loss_D: 0.6792, Loss_G: 2.9751
# Loss_D: 0.8665, Loss_G: 1.1603
# Loss_D: 0.8095, Loss_G: 2.5594
# Loss_D: 0.6146, Loss_G: 3.0084
# Loss_D: 0.8778, Loss_G: 0.8717
# Loss_D: 0.8163, Loss_G: 2.9716
# Loss_D: 0.5526, Loss_G: 2.8712
# Loss_D: 0.5678, Loss_G: 1.5309
# Loss_D: 0.5574, Loss_G: 2.4830
# Loss_D: 0.5236, Loss_G: 2.1116
# Loss_D: 0.4196, Loss_G: 2.4834
# Loss_D: 0.4159, Loss_G: 1.8821
# Loss_D: 0.6400, Loss_G: 3.4920
# Loss_D: 0.5748, Loss_G: 2.0278
# Loss_D: 0.3600, Loss_G: 2.3635
# Loss_D: 0.4120, Loss_G: 2.4922
# Loss_D: 0.4437, Loss_G: 1.9819
# Loss_D: 0.3875, Loss_G: 2.9272
# Loss_D: 0.4458, Loss_G: 2.0994
# Loss_D: 0.4008, Loss_G: 2.3204
# Loss_D: 0.4359, Loss_G: 2.2755
# Loss_D: 0.3929, Loss_G: 2.3205
# Loss_D: 0.4774, Loss_G: 2.8382
# Loss_D: 0.4459, Loss_G: 1.8611
# Loss_D: 0.4147, Loss_G: 3.3689
# Loss_D: 0.4425, Loss_G: 1.9007
# Loss_D: 0.7282, Loss_G: 4.0230
# Loss_D: 0.9946, Loss_G: 0.6866
# Loss_D: 0.9246, Loss_G: 3.7255
# Loss_D: 0.4761, Loss_G: 2.4496
# Loss_D: 0.4037, Loss_G: 1.9525
# Loss_D: 0.3647, Loss_G: 3.3579
# Loss_D: 0.3727, Loss_G: 2.3723
# Loss_D: 0.3474, Loss_G: 2.3904
# Loss_D: 0.3995, Loss_G: 2.7197
# Loss_D: 0.3007, Loss_G: 2.3852
# Loss_D: 0.2907, Loss_G: 2.6801
# Loss_D: 0.3532, Loss_G: 2.2765
# Loss_D: 0.4702, Loss_G: 2.7389
# Loss_D: 0.3741, Loss_G: 2.1993
# Loss_D: 0.4065, Loss_G: 3.0710
# Loss_D: 0.4145, Loss_G: 1.8956
# Loss_D: 0.3272, Loss_G: 2.7909
# Loss_D: 0.2975, Loss_G: 2.4295
# Loss_D: 0.3774, Loss_G: 3.4014
# Loss_D: 0.4749, Loss_G: 1.4906
# Loss_D: 0.5799, Loss_G: 4.4712
# Loss_D: 0.6015, Loss_G: 1.8107
# Loss_D: 0.3905, Loss_G: 2.7166
# Loss_D: 0.3963, Loss_G: 3.1628
# Loss_D: 0.5479, Loss_G: 1.3404
# Loss_D: 0.6653, Loss_G: 5.5443
# Loss_D: 0.7126, Loss_G: 1.8216
# Loss_D: 0.5251, Loss_G: 2.7903
# Loss_D: 0.3668, Loss_G: 3.1671
# Loss_D: 0.3174, Loss_G: 2.4333
# Loss_D: 0.3765, Loss_G: 3.1074
# Loss_D: 0.3301, Loss_G: 3.1313
# Loss_D: 0.3796, Loss_G: 1.7853
# Loss_D: 0.3767, Loss_G: 2.7260
# Loss_D: 0.2511, Loss_G: 3.4586
# Loss_D: 0.2997, Loss_G: 2.3848
# Loss_D: 0.3428, Loss_G: 3.2150
# Loss_D: 0.3646, Loss_G: 2.0815
# Loss_D: 0.3049, Loss_G: 2.3877
# Loss_D: 0.2610, Loss_G: 3.2443
# Loss_D: 0.2845, Loss_G: 3.7673
# Loss_D: 0.3789, Loss_G: 1.8332
# Loss_D: 0.4023, Loss_G: 3.4368
# Loss_D: 0.2586, Loss_G: 2.9594
# Loss_D: 0.3223, Loss_G: 1.9835
# Loss_D: 0.3484, Loss_G: 3.8570
# Loss_D: 0.5600, Loss_G: 1.0272
# Loss_D: 0.8564, Loss_G: 6.6421
# Loss_D: 1.7498, Loss_G: 1.2192
# Loss_D: 0.6709, Loss_G: 6.0601
# Loss_D: 1.8622, Loss_G: 0.0222
# Loss_D: 5.5842, Loss_G: 3.7523
# Loss_D: 0.8108, Loss_G: 4.0152
# Loss_D: 1.4265, Loss_G: 0.2521
# Loss_D: 2.4318, Loss_G: 5.1725
# Loss_D: 2.1989, Loss_G: 1.3125
# Loss_D: 0.9384, Loss_G: 1.7697
# Loss_D: 0.9544, Loss_G: 3.5032
# Loss_D: 0.9808, Loss_G: 1.3185
# Loss_D: 0.9529, Loss_G: 2.7252
# Loss_D: 0.4933, Loss_G: 2.6295
# Loss_D: 0.7237, Loss_G: 1.2296
# Loss_D: 0.9451, Loss_G: 2.9875
# Loss_D: 0.6417, Loss_G: 1.8461
# Loss_D: 0.5353, Loss_G: 1.7182
# Loss_D: 0.2768, Loss_G: 2.7509
# Epoch: 8
# Loss_D: 0.4076, Loss_G: 2.4587
# Loss_D: 0.3999, Loss_G: 2.3944
# Loss_D: 0.6385, Loss_G: 1.3808
# Loss_D: 0.6466, Loss_G: 2.6333
# Loss_D: 0.4223, Loss_G: 2.4785
# Loss_D: 0.3731, Loss_G: 2.1444
# Loss_D: 0.3606, Loss_G: 2.3336
# Loss_D: 0.3670, Loss_G: 2.3490
# Loss_D: 0.3532, Loss_G: 2.5598
# Loss_D: 0.4171, Loss_G: 2.1200
# Loss_D: 0.3511, Loss_G: 2.2770
# Loss_D: 0.3270, Loss_G: 2.6793
# Loss_D: 0.3633, Loss_G: 2.5659
# Loss_D: 0.3154, Loss_G: 2.5820
# Loss_D: 0.4294, Loss_G: 1.6995
# Loss_D: 0.4993, Loss_G: 3.2798
# Loss_D: 0.5339, Loss_G: 1.7595
# Loss_D: 0.3158, Loss_G: 2.3814
# Loss_D: 0.3099, Loss_G: 2.9191
# Loss_D: 0.3147, Loss_G: 2.6427
# Loss_D: 0.2250, Loss_G: 2.4715
# Loss_D: 0.3265, Loss_G: 2.7187
# Loss_D: 0.2319, Loss_G: 3.1664
# Loss_D: 0.2952, Loss_G: 2.3944
# Loss_D: 0.2633, Loss_G: 2.4249
# Loss_D: 0.4116, Loss_G: 2.7807
# Loss_D: 0.3550, Loss_G: 1.8158
# Loss_D: 0.2267, Loss_G: 2.8370
# Loss_D: 0.2664, Loss_G: 3.1172
# Loss_D: 0.2349, Loss_G: 2.6847
# Loss_D: 0.2231, Loss_G: 3.0277
# Loss_D: 0.3143, Loss_G: 2.1722
# Loss_D: 0.3385, Loss_G: 2.5937
# Loss_D: 0.3369, Loss_G: 3.9302
# Loss_D: 0.5532, Loss_G: 1.4419
# Loss_D: 0.4803, Loss_G: 4.0388
# Loss_D: 0.6283, Loss_G: 2.4082
# Loss_D: 0.6462, Loss_G: 6.7686
# Loss_D: 2.8613, Loss_G: 0.3085
# Loss_D: 2.4385, Loss_G: 7.2583
# Loss_D: 3.1582, Loss_G: 0.3223
# Loss_D: 2.3341, Loss_G: 4.6787
# Loss_D: 1.6765, Loss_G: 1.2132
# Loss_D: 0.9229, Loss_G: 2.1822
# Loss_D: 0.9132, Loss_G: 2.2104
# Loss_D: 0.5963, Loss_G: 1.9640
# Loss_D: 0.6876, Loss_G: 1.3168
# Loss_D: 0.8653, Loss_G: 2.6718
# Loss_D: 0.7570, Loss_G: 1.7507
# Loss_D: 0.5213, Loss_G: 1.8549
# Loss_D: 0.6155, Loss_G: 2.7266
# Loss_D: 0.8611, Loss_G: 1.1196
# Loss_D: 0.6046, Loss_G: 2.5467
# Loss_D: 0.4496, Loss_G: 2.5677
# Loss_D: 0.4455, Loss_G: 2.0783
# Loss_D: 0.6397, Loss_G: 1.5308
# Loss_D: 0.6098, Loss_G: 2.9186
# Loss_D: 0.5990, Loss_G: 1.8543
# Loss_D: 0.4844, Loss_G: 1.6675
# Loss_D: 0.5136, Loss_G: 2.9722
# Loss_D: 0.3928, Loss_G: 2.6228
# Loss_D: 0.5350, Loss_G: 1.6327
# Loss_D: 0.4235, Loss_G: 2.6389
# Loss_D: 0.4656, Loss_G: 2.1057
# Loss_D: 0.3945, Loss_G: 2.4439
# Loss_D: 0.3984, Loss_G: 1.9451
# Loss_D: 0.4824, Loss_G: 2.7442
# Loss_D: 0.5693, Loss_G: 1.9023
# Loss_D: 0.3697, Loss_G: 2.0678
# Loss_D: 0.3725, Loss_G: 2.9276
# Loss_D: 0.3913, Loss_G: 2.2224
# Loss_D: 0.3808, Loss_G: 2.1332
# Loss_D: 0.5430, Loss_G: 2.0468
# Loss_D: 0.4325, Loss_G: 2.7368
# Loss_D: 0.3672, Loss_G: 2.1460
# Loss_D: 0.5614, Loss_G: 3.4657
# Loss_D: 0.6318, Loss_G: 1.5244
# Loss_D: 0.6098, Loss_G: 3.5137
# Loss_D: 0.5529, Loss_G: 1.9658
# Loss_D: 0.5503, Loss_G: 2.6680
# Loss_D: 0.3805, Loss_G: 2.5453
# Loss_D: 0.3354, Loss_G: 2.3680
# Loss_D: 0.3486, Loss_G: 2.3893
# Loss_D: 0.4104, Loss_G: 3.1638
# Loss_D: 0.4381, Loss_G: 1.8159
# Loss_D: 0.3893, Loss_G: 2.3403
# Loss_D: 0.3586, Loss_G: 3.6179
# Loss_D: 0.3248, Loss_G: 2.3562
# Loss_D: 0.3012, Loss_G: 2.2136
# Loss_D: 0.4774, Loss_G: 2.9221
# Loss_D: 0.4150, Loss_G: 1.7671
# Loss_D: 0.5160, Loss_G: 3.9483
# Loss_D: 0.4511, Loss_G: 1.9839
# Loss_D: 0.3242, Loss_G: 2.4224
# Loss_D: 0.3786, Loss_G: 2.6273
# Loss_D: 0.4615, Loss_G: 3.3464
# Loss_D: 0.3673, Loss_G: 2.2751
# Loss_D: 0.2794, Loss_G: 2.4429
# Loss_D: 0.3956, Loss_G: 3.6895
# Loss_D: 0.5880, Loss_G: 0.8096
# Loss_D: 0.9369, Loss_G: 5.3130
# Loss_D: 1.2905, Loss_G: 0.8157
# Loss_D: 1.2101, Loss_G: 6.1390
# Loss_D: 2.7719, Loss_G: 0.1430
# Loss_D: 2.1166, Loss_G: 5.9042
# Loss_D: 1.2330, Loss_G: 0.9454
# Loss_D: 1.0703, Loss_G: 3.3343
# Loss_D: 0.9437, Loss_G: 1.8280
# Loss_D: 0.6564, Loss_G: 2.6170
# Loss_D: 0.6200, Loss_G: 1.8092
# Loss_D: 0.6942, Loss_G: 3.1253
# Loss_D: 0.5499, Loss_G: 2.0586
# Loss_D: 0.5280, Loss_G: 1.6791
# Loss_D: 0.4543, Loss_G: 3.3771
# Loss_D: 0.4521, Loss_G: 2.3844
# Loss_D: 0.3733, Loss_G: 1.8426
# Loss_D: 0.4687, Loss_G: 3.2962
# Loss_D: 0.5742, Loss_G: 1.7113
# Loss_D: 0.5546, Loss_G: 2.3847
# Loss_D: 0.4586, Loss_G: 2.8176
# Loss_D: 0.5211, Loss_G: 1.4056
# Loss_D: 0.4910, Loss_G: 2.7464
# Loss_D: 0.3473, Loss_G: 2.8892
# Loss_D: 0.3086, Loss_G: 2.4240
# Loss_D: 0.2880, Loss_G: 2.6075
# Loss_D: 0.3437, Loss_G: 2.9574
# Loss_D: 0.4877, Loss_G: 2.0673
# Loss_D: 0.3376, Loss_G: 1.9921
# Loss_D: 0.3208, Loss_G: 3.0228
# Loss_D: 0.3430, Loss_G: 2.6410
# Loss_D: 0.3343, Loss_G: 2.7360
# Loss_D: 0.3977, Loss_G: 2.0073
# Loss_D: 0.3311, Loss_G: 2.2337
# Loss_D: 0.3202, Loss_G: 3.2667
# Loss_D: 0.4529, Loss_G: 1.7307
# Loss_D: 0.4649, Loss_G: 3.4733
# Loss_D: 0.5559, Loss_G: 1.4761
# Loss_D: 0.5605, Loss_G: 3.7073
# Loss_D: 0.4694, Loss_G: 2.3660
# Loss_D: 0.3886, Loss_G: 2.0702
# Loss_D: 0.3474, Loss_G: 2.9537
# Loss_D: 0.3512, Loss_G: 2.7253
# Loss_D: 0.2787, Loss_G: 2.5997
# Loss_D: 0.4464, Loss_G: 2.4777
# Loss_D: 0.3242, Loss_G: 2.3746
# Loss_D: 0.2541, Loss_G: 3.2080
# Loss_D: 0.2445, Loss_G: 2.9644
# Loss_D: 0.2742, Loss_G: 3.0369
# Loss_D: 0.4019, Loss_G: 1.4504
# Loss_D: 0.5049, Loss_G: 4.1505
# Loss_D: 0.3607, Loss_G: 2.5757
# Loss_D: 0.4761, Loss_G: 2.7235
# Loss_D: 0.2655, Loss_G: 3.1107
# Loss_D: 0.2342, Loss_G: 2.7169
# Loss_D: 0.2551, Loss_G: 2.7529
# Loss_D: 0.2488, Loss_G: 3.3252
# Loss_D: 0.2359, Loss_G: 2.5544
# Epoch: 9
# Loss_D: 0.2794, Loss_G: 3.3002
# Loss_D: 0.2217, Loss_G: 3.6439
# Loss_D: 0.3405, Loss_G: 1.8708
# Loss_D: 0.2386, Loss_G: 3.5756
# Loss_D: 0.2389, Loss_G: 3.6450
# Loss_D: 0.3238, Loss_G: 1.9514
# Loss_D: 0.3912, Loss_G: 4.3525
# Loss_D: 0.6101, Loss_G: 0.8922
# Loss_D: 0.6927, Loss_G: 4.8293
# Loss_D: 0.5010, Loss_G: 2.8809
# Loss_D: 0.2617, Loss_G: 2.9867
# Loss_D: 0.2853, Loss_G: 2.2324
# Loss_D: 0.3503, Loss_G: 3.3127
# Loss_D: 0.2396, Loss_G: 3.8124
# Loss_D: 0.4577, Loss_G: 1.3821
# Loss_D: 0.6190, Loss_G: 4.8778
# Loss_D: 0.6491, Loss_G: 1.5508
# Loss_D: 0.5905, Loss_G: 4.3032
# Loss_D: 0.3854, Loss_G: 3.0334
# Loss_D: 0.2661, Loss_G: 2.4885
# Loss_D: 0.3338, Loss_G: 3.7024
# Loss_D: 0.4514, Loss_G: 1.5309
# Loss_D: 0.3903, Loss_G: 3.9236
# Loss_D: 0.4498, Loss_G: 1.5787
# Loss_D: 0.5982, Loss_G: 4.4829
# Loss_D: 0.6111, Loss_G: 1.6981
# Loss_D: 0.3212, Loss_G: 3.0488
# Loss_D: 0.2611, Loss_G: 3.6807
# Loss_D: 0.3250, Loss_G: 2.1970
# Loss_D: 0.3161, Loss_G: 2.5905
# Loss_D: 0.2477, Loss_G: 3.4248
# Loss_D: 0.2655, Loss_G: 2.8531
# Loss_D: 0.3085, Loss_G: 2.7988
# Loss_D: 0.2741, Loss_G: 2.4134
# Loss_D: 0.2838, Loss_G: 3.1756
# Loss_D: 0.1930, Loss_G: 3.4603
# Loss_D: 0.2402, Loss_G: 2.5947
# Loss_D: 0.3290, Loss_G: 2.5823
# Loss_D: 0.3227, Loss_G: 2.7882
# Loss_D: 0.3086, Loss_G: 2.9826
# Loss_D: 0.2884, Loss_G: 3.5142
# Loss_D: 0.3732, Loss_G: 1.6104
# Loss_D: 0.6797, Loss_G: 6.1263
# Loss_D: 1.2027, Loss_G: 2.3377
# Loss_D: 0.3630, Loss_G: 2.7667
# Loss_D: 0.6418, Loss_G: 2.2312
# Loss_D: 1.0475, Loss_G: 0.6896
# Loss_D: 1.0327, Loss_G: 8.1205
# Loss_D: 5.0517, Loss_G: 0.0634
# Loss_D: 4.0272, Loss_G: 6.0291
# Loss_D: 1.6889, Loss_G: 1.0348
# Loss_D: 1.3076, Loss_G: 3.9572
# Loss_D: 1.0249, Loss_G: 1.1190
# Loss_D: 1.1339, Loss_G: 3.0787
# Loss_D: 0.7499, Loss_G: 2.8585
# Loss_D: 1.0611, Loss_G: 0.5563
# Loss_D: 1.4950, Loss_G: 5.1322
# Loss_D: 1.1432, Loss_G: 1.5999
# Loss_D: 0.7812, Loss_G: 2.2402
# Loss_D: 0.5208, Loss_G: 3.8324
# Loss_D: 0.8955, Loss_G: 1.6174
# Loss_D: 0.7210, Loss_G: 2.4321
# Loss_D: 0.5436, Loss_G: 2.4423
# Loss_D: 0.4142, Loss_G: 2.7097
# Loss_D: 0.4286, Loss_G: 2.3957
# Loss_D: 0.5333, Loss_G: 2.2089
# Loss_D: 0.5589, Loss_G: 2.5568
# Loss_D: 0.4131, Loss_G: 2.4716
# Loss_D: 0.5443, Loss_G: 1.9359
# Loss_D: 0.4855, Loss_G: 2.7971
# Loss_D: 0.4653, Loss_G: 2.5895
# Loss_D: 0.3704, Loss_G: 1.8262
# Loss_D: 0.4521, Loss_G: 3.6008
# Loss_D: 0.6107, Loss_G: 1.5755
# Loss_D: 0.6569, Loss_G: 3.9206
# Loss_D: 0.6056, Loss_G: 1.7868
# Loss_D: 0.4616, Loss_G: 2.9658
# Loss_D: 0.4639, Loss_G: 2.6730
# Loss_D: 0.4129, Loss_G: 2.1701
# Loss_D: 0.3686, Loss_G: 2.6047
# Loss_D: 0.4927, Loss_G: 2.1860
# Loss_D: 0.5032, Loss_G: 2.4813
# Loss_D: 0.3516, Loss_G: 2.7933
# Loss_D: 0.2850, Loss_G: 2.2826
# Loss_D: 0.6311, Loss_G: 4.2840
# Loss_D: 0.8015, Loss_G: 1.4143
# Loss_D: 0.5874, Loss_G: 3.1333
# Loss_D: 0.4911, Loss_G: 2.7473
# Loss_D: 0.3511, Loss_G: 2.4708
# Loss_D: 0.2553, Loss_G: 2.6773
# Loss_D: 0.3514, Loss_G: 2.1184
# Loss_D: 0.4065, Loss_G: 2.8515
# Loss_D: 0.2246, Loss_G: 3.3652
# Loss_D: 0.2770, Loss_G: 2.1072
# Loss_D: 0.3248, Loss_G: 2.8333
# Loss_D: 0.2855, Loss_G: 2.5080
# Loss_D: 0.4374, Loss_G: 2.5830
# Loss_D: 0.2448, Loss_G: 3.1284
# Loss_D: 0.2533, Loss_G: 3.1446
# Loss_D: 0.3943, Loss_G: 1.2983
# Loss_D: 0.9443, Loss_G: 6.2501
# Loss_D: 1.3346, Loss_G: 1.8177
# Loss_D: 0.7524, Loss_G: 3.6897
# Loss_D: 0.9179, Loss_G: 0.4458
# Loss_D: 1.8836, Loss_G: 5.9594
# Loss_D: 1.5960, Loss_G: 1.2638
# Loss_D: 0.9738, Loss_G: 3.2600
# Loss_D: 0.6218, Loss_G: 2.0273
# Loss_D: 0.5274, Loss_G: 2.2113
# Loss_D: 0.4681, Loss_G: 3.2611
# Loss_D: 0.4803, Loss_G: 2.1900
# Loss_D: 0.4690, Loss_G: 2.9226
# Loss_D: 0.4145, Loss_G: 2.0573
# Loss_D: 0.6804, Loss_G: 3.1055
# Loss_D: 0.5525, Loss_G: 1.9032
# Loss_D: 0.4055, Loss_G: 2.3823
# Loss_D: 0.3313, Loss_G: 3.2620
# Loss_D: 0.2414, Loss_G: 2.8645
# Loss_D: 0.3847, Loss_G: 2.4416
# Loss_D: 0.2791, Loss_G: 3.3884
# Loss_D: 0.3881, Loss_G: 1.9700
# Loss_D: 0.3558, Loss_G: 2.7963
# Loss_D: 0.2651, Loss_G: 2.9838
# Loss_D: 0.3581, Loss_G: 2.6292
# Loss_D: 0.2962, Loss_G: 2.2515
# Loss_D: 0.3291, Loss_G: 3.9466
# Loss_D: 0.4902, Loss_G: 1.7507
# Loss_D: 0.5265, Loss_G: 3.3855
# Loss_D: 0.3625, Loss_G: 2.4797
# Loss_D: 0.2824, Loss_G: 2.5513
# ...
# Loss_D: 0.6355, Loss_G: 1.6888
# Loss_D: 0.6173, Loss_G: 2.0305
# Loss_D: 0.6045, Loss_G: 2.7074
# Loss_D: 0.7500, Loss_G: 2.1290
# Loss_D: 0.6177, Loss_G: 1.6299
# Loss_D: 0.5698, Loss_G: 2.7130
# Loss_D: 0.6440, Loss_G: 2.6095
# Loss_D: 0.9061, Loss_G: 1.2456
# Loss_D: 0.8153, Loss_G: 2.8083
# Loss_D: 0.5346, Loss_G: 2.6011
# Loss_D: 0.4340, Loss_G: 2.1072
# Loss_D: 0.3657, Loss_G: 2.4505
# Loss_D: 0.4777, Loss_G: 2.7641
# Loss_D: 0.4505, Loss_G: 2.6075
# Loss_D: 0.3116, Loss_G: 2.9336
# Loss_D: 0.4150, Loss_G: 2.5424
# Loss_D: 0.5723, Loss_G: 2.1360
# Loss_D: 0.4256, Loss_G: 2.8351
# Loss_D: 0.2959, Loss_G: 2.7626
# Loss_D: 0.4653, Loss_G: 2.5196
# Loss_D: 0.3074, Loss_G: 2.6734
# Loss_D: 0.2237, Loss_G: 3.0580
# Loss_D: 0.2423, Loss_G: 3.2335
# Loss_D: 0.3643, Loss_G: 2.2788
# Loss_D: 0.2494, Loss_G: 3.0322
# Loss_D: 0.1976, Loss_G: 3.3952
# Loss_D: 0.2509, Loss_G: 3.1275
# Loss_D: 0.1915, Loss_G: 3.1035
# Loss_D: 0.3215, Loss_G: 3.1834
# Loss_D: 0.3288, Loss_G: 2.4388
# Loss_D: 0.1995, Loss_G: 3.1193
# Loss_D: 0.2851, Loss_G: 2.8861
# Loss_D: 0.3167, Loss_G: 2.6020
# Loss_D: 0.1975, Loss_G: 3.2827
# Loss_D: 0.2080, Loss_G: 4.2343
# Loss_D: 0.2597, Loss_G: 3.2399
# Loss_D: 0.2425, Loss_G: 2.5637
# Loss_D: 0.1935, Loss_G: 3.5301
# Loss_D: 0.1461, Loss_G: 3.7780
# Loss_D: 0.1994, Loss_G: 2.9743
# Loss_D: 0.2491, Loss_G: 3.4511
# Loss_D: 0.2099, Loss_G: 3.3379
# Loss_D: 0.2778, Loss_G: 3.0683
# Loss_D: 0.1631, Loss_G: 3.2783
# Epoch: 97
# Loss_D: 0.2400, Loss_G: 3.5098
# Loss_D: 0.2124, Loss_G: 3.7394
# Loss_D: 0.1318, Loss_G: 3.7136
# Loss_D: 0.1616, Loss_G: 3.4298
# Loss_D: 0.1090, Loss_G: 3.5965
# Loss_D: 0.1294, Loss_G: 3.6902
# Loss_D: 0.1317, Loss_G: 4.1014
# Loss_D: 0.1649, Loss_G: 3.3041
# Loss_D: 0.1288, Loss_G: 3.3573
# Loss_D: 0.1401, Loss_G: 3.4904
# Loss_D: 0.2285, Loss_G: 4.7866
# Loss_D: 0.2962, Loss_G: 2.9812
# Loss_D: 0.2129, Loss_G: 3.6796
# Loss_D: 0.1532, Loss_G: 4.1445
# Loss_D: 0.3525, Loss_G: 2.1371
# Loss_D: 0.3186, Loss_G: 4.9749
# Loss_D: 0.2067, Loss_G: 3.5790
# Loss_D: 0.0802, Loss_G: 3.7016
# Loss_D: 0.1610, Loss_G: 3.9094
# Loss_D: 0.1692, Loss_G: 3.4802
# Loss_D: 0.1216, Loss_G: 4.0770
# Loss_D: 0.1403, Loss_G: 3.7500
# Loss_D: 0.0971, Loss_G: 3.9118
# Loss_D: 0.1200, Loss_G: 3.4021
# Loss_D: 0.0996, Loss_G: 4.1182
# Loss_D: 0.1309, Loss_G: 4.0397
# Loss_D: 0.1576, Loss_G: 2.9294
# Loss_D: 0.1667, Loss_G: 4.5287
# Loss_D: 0.1722, Loss_G: 3.7635
# Loss_D: 0.1298, Loss_G: 3.9655
# Loss_D: 0.1127, Loss_G: 3.6017
# Loss_D: 0.1203, Loss_G: 4.3934
# Loss_D: 0.0769, Loss_G: 4.5194
# Loss_D: 0.0679, Loss_G: 3.8610
# Loss_D: 0.1020, Loss_G: 3.9714
# Loss_D: 0.0824, Loss_G: 4.0997
# Loss_D: 0.0471, Loss_G: 4.4972
# Loss_D: 0.0862, Loss_G: 4.0194
# Loss_D: 0.0904, Loss_G: 4.2193
# Loss_D: 0.0844, Loss_G: 4.0407
# Loss_D: 0.0948, Loss_G: 3.8789
# Loss_D: 0.0527, Loss_G: 4.1795
# Loss_D: 0.0541, Loss_G: 4.4812
# Loss_D: 0.0677, Loss_G: 4.2474
# Loss_D: 0.0809, Loss_G: 4.6121
# Loss_D: 0.0869, Loss_G: 4.1178
# Loss_D: 0.0772, Loss_G: 3.5585
# Loss_D: 0.0711, Loss_G: 4.2740
# Loss_D: 0.0944, Loss_G: 3.5586
# Loss_D: 0.1404, Loss_G: 5.1603
# Loss_D: 0.1201, Loss_G: 4.0284
# Loss_D: 0.0595, Loss_G: 3.8731
# Loss_D: 0.0552, Loss_G: 4.2689
# Loss_D: 0.0841, Loss_G: 4.7398
# Loss_D: 0.0438, Loss_G: 4.8510
# Loss_D: 0.1369, Loss_G: 2.6283
# Loss_D: 0.2882, Loss_G: 6.5414
# Loss_D: 0.2950, Loss_G: 3.1898
# Loss_D: 0.2397, Loss_G: 5.0467
# Loss_D: 0.2907, Loss_G: 1.9546
# Loss_D: 0.2358, Loss_G: 6.4765
# Loss_D: 0.5017, Loss_G: 1.3444
# Loss_D: 0.7235, Loss_G: 10.5372
# Loss_D: 4.9943, Loss_G: 0.6438
# Loss_D: 1.2453, Loss_G: 5.0341
# Loss_D: 0.7065, Loss_G: 2.1222
# Loss_D: 1.1269, Loss_G: 3.2041
# Loss_D: 0.7685, Loss_G: 1.4145
# Loss_D: 0.7345, Loss_G: 4.3917
# Loss_D: 0.9794, Loss_G: 0.9520
# Loss_D: 0.6507, Loss_G: 4.2804
# Loss_D: 0.4010, Loss_G: 3.3824
# Loss_D: 0.3242, Loss_G: 2.6444
# Loss_D: 0.4150, Loss_G: 4.4515
# Loss_D: 0.4132, Loss_G: 2.9791
# Loss_D: 0.2288, Loss_G: 3.4735
# Loss_D: 0.3213, Loss_G: 3.4655
# Loss_D: 0.2050, Loss_G: 3.5515
# Loss_D: 0.2526, Loss_G: 3.7687
# Loss_D: 0.2654, Loss_G: 4.6756
# Loss_D: 0.5001, Loss_G: 1.4648
# Loss_D: 0.5483, Loss_G: 5.6577
# Loss_D: 0.3434, Loss_G: 3.2361
# Loss_D: 0.1619, Loss_G: 3.6238
# Loss_D: 0.1119, Loss_G: 4.3365
# Loss_D: 0.0611, Loss_G: 4.6832
# Loss_D: 0.1061, Loss_G: 4.0279
# Loss_D: 0.1479, Loss_G: 3.1500
# Loss_D: 0.2508, Loss_G: 4.7666
# Loss_D: 0.1754, Loss_G: 3.8160
# Loss_D: 0.0909, Loss_G: 3.8082
# Loss_D: 0.1112, Loss_G: 4.4447
# Loss_D: 0.1093, Loss_G: 3.8777
# Loss_D: 0.1200, Loss_G: 4.1536
# Loss_D: 0.1060, Loss_G: 4.6816
# Loss_D: 0.1281, Loss_G: 3.5979
# Loss_D: 0.0935, Loss_G: 3.7756
# Loss_D: 0.0920, Loss_G: 4.6765
# Loss_D: 0.0579, Loss_G: 5.0261
# Loss_D: 0.0813, Loss_G: 4.0331
# Loss_D: 0.1635, Loss_G: 5.4869
# Loss_D: 0.1028, Loss_G: 4.9367
# Loss_D: 0.0764, Loss_G: 3.2027
# Loss_D: 0.1261, Loss_G: 5.3948
# Loss_D: 0.0944, Loss_G: 4.6184
# Loss_D: 0.0384, Loss_G: 4.5846
# Loss_D: 0.0578, Loss_G: 4.7257
# Loss_D: 0.0659, Loss_G: 4.6541
# Loss_D: 0.0418, Loss_G: 4.8104
# Loss_D: 0.0469, Loss_G: 4.8085
# Loss_D: 0.0292, Loss_G: 4.8257
# Loss_D: 0.0413, Loss_G: 4.9651
# Loss_D: 0.0426, Loss_G: 4.8372
# Loss_D: 0.0489, Loss_G: 3.9184
# Loss_D: 0.0854, Loss_G: 5.2496
# Loss_D: 0.0951, Loss_G: 4.0024
# Loss_D: 0.0545, Loss_G: 4.1649
# Loss_D: 0.0593, Loss_G: 5.0976
# Loss_D: 0.0465, Loss_G: 4.9419
# Loss_D: 0.0402, Loss_G: 4.5633
# Loss_D: 0.0697, Loss_G: 4.6910
# Loss_D: 0.0546, Loss_G: 4.7785
# Loss_D: 0.0437, Loss_G: 5.1990
# Loss_D: 0.0369, Loss_G: 4.7127
# Loss_D: 0.0389, Loss_G: 4.7451
# Loss_D: 0.0380, Loss_G: 4.8428
# Loss_D: 0.0391, Loss_G: 5.0573
# Loss_D: 0.0349, Loss_G: 5.0359
# Loss_D: 0.0321, Loss_G: 4.9698
# Loss_D: 0.0329, Loss_G: 4.6546
# Loss_D: 0.0286, Loss_G: 4.9832
# Loss_D: 0.0219, Loss_G: 5.2858
# Loss_D: 0.0288, Loss_G: 5.1678
# Loss_D: 0.0722, Loss_G: 5.4411
# Loss_D: 0.1046, Loss_G: 2.9242
# Loss_D: 0.0871, Loss_G: 5.0780
# Loss_D: 0.0219, Loss_G: 5.6593
# Loss_D: 0.0588, Loss_G: 4.2497
# Loss_D: 0.0635, Loss_G: 5.2210
# Loss_D: 0.0526, Loss_G: 4.6343
# Loss_D: 0.0240, Loss_G: 5.1569
# Loss_D: 0.0262, Loss_G: 5.1149
# Loss_D: 0.0334, Loss_G: 5.2781
# Loss_D: 0.0462, Loss_G: 4.8857
# Loss_D: 0.0391, Loss_G: 4.8882
# Loss_D: 0.0276, Loss_G: 4.7913
# Loss_D: 0.0214, Loss_G: 5.1573
# Loss_D: 0.0528, Loss_G: 5.7106
# Loss_D: 0.0721, Loss_G: 4.1150
# Loss_D: 0.0923, Loss_G: 6.0383
# Loss_D: 0.0409, Loss_G: 5.6821
# Loss_D: 0.0367, Loss_G: 4.9028
# Loss_D: 0.0433, Loss_G: 4.7250
# Loss_D: 0.0213, Loss_G: 5.3729
# Loss_D: 0.0151, Loss_G: 5.6920
# Loss_D: 0.0297, Loss_G: 5.0873
# Loss_D: 0.0422, Loss_G: 5.1707
# Epoch: 98
# Loss_D: 0.0164, Loss_G: 5.6448
# Loss_D: 0.0181, Loss_G: 5.5030
# Loss_D: 0.0194, Loss_G: 5.2551
# Loss_D: 0.0547, Loss_G: 4.7490
# Loss_D: 0.0107, Loss_G: 6.3398
# Loss_D: 0.0384, Loss_G: 4.9059
# Loss_D: 0.0314, Loss_G: 4.7185
# Loss_D: 0.0353, Loss_G: 5.3946
# Loss_D: 0.0431, Loss_G: 5.0237
# Loss_D: 0.0244, Loss_G: 5.2028
# Loss_D: 0.0282, Loss_G: 5.6317
# Loss_D: 0.0524, Loss_G: 4.8451
# Loss_D: 0.0170, Loss_G: 4.5543
# Loss_D: 0.0514, Loss_G: 6.1045
# Loss_D: 0.0282, Loss_G: 6.1602
# Loss_D: 0.0278, Loss_G: 5.5246
# Loss_D: 0.0421, Loss_G: 4.0568
# Loss_D: 0.0296, Loss_G: 5.0196
# Loss_D: 0.0198, Loss_G: 5.5563
# Loss_D: 0.0193, Loss_G: 5.7305
# Loss_D: 0.0143, Loss_G: 5.8894
# Loss_D: 0.0321, Loss_G: 5.2262
# Loss_D: 0.0221, Loss_G: 5.5213
# Loss_D: 0.0213, Loss_G: 5.0940
# Loss_D: 0.0237, Loss_G: 5.1088
# Loss_D: 0.0213, Loss_G: 5.3678
# Loss_D: 0.0165, Loss_G: 5.8632
# Loss_D: 0.0170, Loss_G: 5.9364
# Loss_D: 0.0186, Loss_G: 5.4655
# Loss_D: 0.0206, Loss_G: 5.5707
# Loss_D: 0.0216, Loss_G: 5.4340
# Loss_D: 0.0108, Loss_G: 5.6382
# Loss_D: 0.0163, Loss_G: 5.3988
# Loss_D: 0.0101, Loss_G: 6.0122
# Loss_D: 0.0189, Loss_G: 5.4299
# Loss_D: 0.0147, Loss_G: 5.8063
# Loss_D: 0.0137, Loss_G: 5.7007
# Loss_D: 0.0177, Loss_G: 6.3292
# Loss_D: 0.0097, Loss_G: 5.4422
# Loss_D: 0.0103, Loss_G: 6.1938
# Loss_D: 0.0279, Loss_G: 5.0748
# Loss_D: 0.0197, Loss_G: 5.8583
# Loss_D: 0.0061, Loss_G: 6.4714
# Loss_D: 0.0122, Loss_G: 5.8387
# Loss_D: 0.0112, Loss_G: 5.9377
# Loss_D: 0.0213, Loss_G: 5.6007
# Loss_D: 0.0169, Loss_G: 6.1196
# Loss_D: 0.0167, Loss_G: 5.3937
# Loss_D: 0.0087, Loss_G: 6.4974
# Loss_D: 0.0228, Loss_G: 5.2050
# Loss_D: 0.0088, Loss_G: 6.3331
# Loss_D: 0.0222, Loss_G: 5.3890
# Loss_D: 0.0136, Loss_G: 5.7209
# Loss_D: 0.0102, Loss_G: 6.2071
# Loss_D: 0.0216, Loss_G: 5.3478
# Loss_D: 0.0157, Loss_G: 5.4328
# Loss_D: 0.0062, Loss_G: 6.1237
# Loss_D: 0.0081, Loss_G: 6.0347
# Loss_D: 0.0180, Loss_G: 5.6185
# Loss_D: 0.0125, Loss_G: 6.0124
# Loss_D: 0.0118, Loss_G: 5.8930
# Loss_D: 0.0197, Loss_G: 5.2358
# Loss_D: 0.0200, Loss_G: 5.4051
# Loss_D: 0.0287, Loss_G: 5.0051
# Loss_D: 0.0094, Loss_G: 5.6892
# Loss_D: 0.0147, Loss_G: 5.6423
# Loss_D: 0.0287, Loss_G: 5.8609
# Loss_D: 0.0239, Loss_G: 6.0070
# Loss_D: 0.0151, Loss_G: 5.2535
# Loss_D: 0.0049, Loss_G: 6.2395
# Loss_D: 0.0115, Loss_G: 5.7250
# Loss_D: 0.0133, Loss_G: 5.8202
# Loss_D: 0.0113, Loss_G: 5.7480
# Loss_D: 0.0094, Loss_G: 5.9253
# Loss_D: 0.0084, Loss_G: 6.1191
# Loss_D: 0.0137, Loss_G: 5.7344
# Loss_D: 0.0133, Loss_G: 5.6525
# Loss_D: 0.0163, Loss_G: 5.5258
# Loss_D: 0.0100, Loss_G: 5.8887
# Loss_D: 0.0115, Loss_G: 5.6619
# Loss_D: 0.0192, Loss_G: 5.8389
# Loss_D: 0.0188, Loss_G: 5.9697
# Loss_D: 0.0190, Loss_G: 5.4030
# Loss_D: 0.0154, Loss_G: 5.5178
# Loss_D: 0.0114, Loss_G: 6.0758
# Loss_D: 0.0134, Loss_G: 5.4663
# Loss_D: 0.0242, Loss_G: 5.7240
# Loss_D: 0.0199, Loss_G: 5.9252
# Loss_D: 0.0267, Loss_G: 5.6655
# Loss_D: 0.0263, Loss_G: 4.2763
# Loss_D: 0.0077, Loss_G: 5.3612
# Loss_D: 0.0067, Loss_G: 5.9044
# Loss_D: 0.0642, Loss_G: 7.8210
# Loss_D: 0.0442, Loss_G: 6.9848
# Loss_D: 0.0410, Loss_G: 4.1896
# Loss_D: 0.0318, Loss_G: 4.6657
# Loss_D: 0.0298, Loss_G: 6.3648
# Loss_D: 0.0267, Loss_G: 5.8971
# Loss_D: 0.0233, Loss_G: 5.8319
# Loss_D: 0.0143, Loss_G: 5.2100
# Loss_D: 0.0124, Loss_G: 5.3618
# Loss_D: 0.0076, Loss_G: 6.2820
# Loss_D: 0.0051, Loss_G: 6.7134
# Loss_D: 0.0232, Loss_G: 5.7417
# Loss_D: 0.0132, Loss_G: 6.2168
# Loss_D: 0.0408, Loss_G: 3.9374
# Loss_D: 0.0104, Loss_G: 5.0814
# Loss_D: 0.0068, Loss_G: 5.8494
# Loss_D: 0.0208, Loss_G: 5.9971
# Loss_D: 0.0166, Loss_G: 6.3364
# Loss_D: 0.0211, Loss_G: 6.0878
# Loss_D: 0.0114, Loss_G: 5.6988
# Loss_D: 0.0154, Loss_G: 5.2521
# Loss_D: 0.0062, Loss_G: 6.0869
# Loss_D: 0.0115, Loss_G: 5.9704
# Loss_D: 0.0182, Loss_G: 6.0884
# Loss_D: 0.0146, Loss_G: 6.0639
# Loss_D: 0.0148, Loss_G: 5.5972
# Loss_D: 0.0095, Loss_G: 6.2043
# Loss_D: 0.0105, Loss_G: 5.9185
# Loss_D: 0.0152, Loss_G: 5.9325
# Loss_D: 0.0129, Loss_G: 5.5138
# Loss_D: 0.0101, Loss_G: 5.7947
# Loss_D: 0.0118, Loss_G: 5.9568
# Loss_D: 0.0059, Loss_G: 6.5386
# Loss_D: 0.0129, Loss_G: 6.4409
# Loss_D: 0.0057, Loss_G: 6.1636
# Loss_D: 0.0126, Loss_G: 5.6242
# Loss_D: 0.0129, Loss_G: 5.9383
# Loss_D: 0.0113, Loss_G: 5.9721
# Loss_D: 0.0081, Loss_G: 7.0322
# Loss_D: 0.0093, Loss_G: 5.8269
# Loss_D: 0.0124, Loss_G: 5.6328
# Loss_D: 0.0103, Loss_G: 5.8084
# Loss_D: 0.0098, Loss_G: 6.1765
# Loss_D: 0.0043, Loss_G: 7.0921
# Loss_D: 0.0076, Loss_G: 5.9931
# Loss_D: 0.0053, Loss_G: 6.5383
# Loss_D: 0.0148, Loss_G: 5.6551
# Loss_D: 0.0089, Loss_G: 6.4436
# Loss_D: 0.0095, Loss_G: 6.0771
# Loss_D: 0.0106, Loss_G: 5.9165
# Loss_D: 0.0129, Loss_G: 5.9125
# Loss_D: 0.0060, Loss_G: 6.5401
# Loss_D: 0.0163, Loss_G: 5.7353
# Loss_D: 0.0089, Loss_G: 6.3409
# Loss_D: 0.0097, Loss_G: 6.0552
# Loss_D: 0.0119, Loss_G: 6.2927
# Loss_D: 0.0140, Loss_G: 5.4812
# Loss_D: 0.0170, Loss_G: 5.4555
# Loss_D: 0.0068, Loss_G: 6.2928
# Loss_D: 0.0115, Loss_G: 6.1161
# Loss_D: 0.0136, Loss_G: 5.6330
# Loss_D: 0.0052, Loss_G: 6.2178
# Loss_D: 0.0517, Loss_G: 7.6343
# Loss_D: 0.1145, Loss_G: 2.6047
# Loss_D: 0.6224, Loss_G: 20.3828
# Epoch: 99
# Loss_D: 10.6999, Loss_G: 4.1641
# Loss_D: 1.7282, Loss_G: 0.0600
# Loss_D: 4.7186, Loss_G: 5.5813
# Loss_D: 2.2739, Loss_G: 1.2161
# Loss_D: 1.1831, Loss_G: 2.3645
# Loss_D: 1.3188, Loss_G: 3.4825
# Loss_D: 1.7129, Loss_G: 0.9912
# Loss_D: 1.7172, Loss_G: 2.6434
# Loss_D: 0.9512, Loss_G: 2.0992
# Loss_D: 0.7159, Loss_G: 1.9184
# Loss_D: 0.8605, Loss_G: 2.1653
# Loss_D: 0.8171, Loss_G: 1.7547
# Loss_D: 0.6171, Loss_G: 3.1483
# Loss_D: 0.6997, Loss_G: 2.3159
# Loss_D: 0.5806, Loss_G: 2.2800
# Loss_D: 0.4856, Loss_G: 1.9794
# Loss_D: 0.5442, Loss_G: 3.1578
# Loss_D: 0.7115, Loss_G: 1.7787
# Loss_D: 0.5037, Loss_G: 2.6680
# Loss_D: 0.3641, Loss_G: 3.0797
# Loss_D: 0.4407, Loss_G: 1.8797
# Loss_D: 0.9545, Loss_G: 4.3320
# Loss_D: 1.1916, Loss_G: 1.5048
# Loss_D: 0.7977, Loss_G: 3.0063
# Loss_D: 0.4014, Loss_G: 3.8518
# Loss_D: 0.5610, Loss_G: 2.2763
# Loss_D: 0.3862, Loss_G: 2.5251
# Loss_D: 0.3810, Loss_G: 3.2359
# Loss_D: 0.3138, Loss_G: 2.9178
# Loss_D: 0.2701, Loss_G: 2.7403
# Loss_D: 0.3725, Loss_G: 3.3680
# Loss_D: 0.2960, Loss_G: 3.1293
# Loss_D: 0.3448, Loss_G: 2.2727
# Loss_D: 0.4668, Loss_G: 4.1049
# Loss_D: 0.2434, Loss_G: 3.4158
# Loss_D: 0.1611, Loss_G: 3.2372
# Loss_D: 0.3377, Loss_G: 3.6055
# Loss_D: 0.1758, Loss_G: 3.7595
# Loss_D: 0.3233, Loss_G: 2.5576
# Loss_D: 0.2932, Loss_G: 3.7742
# Loss_D: 0.3485, Loss_G: 1.8039
# Loss_D: 0.4043, Loss_G: 4.9266
# Loss_D: 0.1892, Loss_G: 4.1349
# Loss_D: 0.3397, Loss_G: 2.2170
# Loss_D: 0.2991, Loss_G: 4.1527
# Loss_D: 0.1946, Loss_G: 3.9122
# Loss_D: 0.2597, Loss_G: 2.3691
# Loss_D: 0.3176, Loss_G: 5.1891
# Loss_D: 0.3073, Loss_G: 2.9547
# Loss_D: 0.2218, Loss_G: 3.7866
# Loss_D: 0.1436, Loss_G: 3.7563
# Loss_D: 0.1895, Loss_G: 4.0625
# Loss_D: 0.1413, Loss_G: 4.0271
# Loss_D: 0.1228, Loss_G: 3.4851
# Loss_D: 0.0971, Loss_G: 3.7873
# Loss_D: 0.1795, Loss_G: 4.5770
# Loss_D: 0.2108, Loss_G: 2.8668
# Loss_D: 0.1880, Loss_G: 4.0083
# Loss_D: 0.1040, Loss_G: 4.4717
# Loss_D: 0.1174, Loss_G: 4.2243
# Loss_D: 0.1368, Loss_G: 3.5447
# Loss_D: 0.1062, Loss_G: 3.9953
# Loss_D: 0.1262, Loss_G: 3.6044
# Loss_D: 0.0885, Loss_G: 4.3449
# Loss_D: 0.0919, Loss_G: 3.9839
# Loss_D: 0.0976, Loss_G: 4.7917
# Loss_D: 0.0709, Loss_G: 4.6355
# Loss_D: 0.0959, Loss_G: 3.6258
# Loss_D: 0.0960, Loss_G: 3.7740
# Loss_D: 0.0826, Loss_G: 4.6454
# Loss_D: 0.0603, Loss_G: 4.6817
# Loss_D: 0.0620, Loss_G: 4.4907
# Loss_D: 0.0868, Loss_G: 3.5028
# Loss_D: 0.0779, Loss_G: 4.6518
# Loss_D: 0.0800, Loss_G: 4.0299
# Loss_D: 0.0689, Loss_G: 4.4335
# Loss_D: 0.0687, Loss_G: 4.7770
# Loss_D: 0.1108, Loss_G: 4.7166
# Loss_D: 0.1127, Loss_G: 3.4944
# Loss_D: 0.0722, Loss_G: 4.3400
# Loss_D: 0.0747, Loss_G: 4.0347
# Loss_D: 0.1164, Loss_G: 5.5531
# Loss_D: 0.1267, Loss_G: 3.9452
# Loss_D: 0.0884, Loss_G: 3.8418
# Loss_D: 0.1482, Loss_G: 6.0394
# Loss_D: 0.2215, Loss_G: 2.6291
# Loss_D: 0.1420, Loss_G: 4.9465
# Loss_D: 0.0955, Loss_G: 4.9975
# Loss_D: 0.2050, Loss_G: 1.5713
# Loss_D: 0.3121, Loss_G: 7.8915
# Loss_D: 0.4219, Loss_G: 1.9716
# Loss_D: 0.9034, Loss_G: 13.4632
# Loss_D: 7.9801, Loss_G: 3.4894
# Loss_D: 0.6398, Loss_G: 0.3468
# Loss_D: 2.0314, Loss_G: 9.0652
# Loss_D: 4.8904, Loss_G: 1.0417
# Loss_D: 2.5647, Loss_G: 2.6399
# Loss_D: 1.2165, Loss_G: 2.0476
# Loss_D: 1.5770, Loss_G: 1.8752
# Loss_D: 1.2802, Loss_G: 2.4125
# Loss_D: 0.8253, Loss_G: 2.0352
# Loss_D: 0.5907, Loss_G: 2.6359
# Loss_D: 0.8414, Loss_G: 2.4065
# Loss_D: 0.5263, Loss_G: 3.3193
# Loss_D: 0.4102, Loss_G: 2.9936
# Loss_D: 0.3451, Loss_G: 2.2341
# Loss_D: 0.6600, Loss_G: 4.3806
# Loss_D: 0.7132, Loss_G: 1.5312
# Loss_D: 0.5952, Loss_G: 4.3002
# Loss_D: 0.4619, Loss_G: 2.6739
# Loss_D: 0.5204, Loss_G: 3.4726
# Loss_D: 0.3883, Loss_G: 3.8888
# Loss_D: 0.3160, Loss_G: 2.6171
# Loss_D: 0.3119, Loss_G: 3.2359
# Loss_D: 0.1479, Loss_G: 4.0546
# Loss_D: 0.2159, Loss_G: 4.0465
# Loss_D: 0.2857, Loss_G: 2.1825
# Loss_D: 0.3758, Loss_G: 5.2343
# Loss_D: 0.3302, Loss_G: 3.1587
# Loss_D: 0.2153, Loss_G: 3.5436
# Loss_D: 0.2894, Loss_G: 3.6681
# Loss_D: 0.1429, Loss_G: 3.6919
# Loss_D: 0.0841, Loss_G: 4.0510
# Loss_D: 0.1823, Loss_G: 4.5068
# Loss_D: 0.1634, Loss_G: 3.4154
# Loss_D: 0.3416, Loss_G: 4.9397
# Loss_D: 0.2049, Loss_G: 3.8015
# Loss_D: 0.1288, Loss_G: 2.8279
# Loss_D: 0.1382, Loss_G: 4.3497
# Loss_D: 0.0943, Loss_G: 4.3549
# Loss_D: 0.2018, Loss_G: 3.2413
# Loss_D: 0.1119, Loss_G: 3.7797
# Loss_D: 0.2018, Loss_G: 4.9440
# Loss_D: 0.2308, Loss_G: 2.3420
# Loss_D: 0.3146, Loss_G: 6.2552
# Loss_D: 0.4568, Loss_G: 1.6121
# Loss_D: 0.3827, Loss_G: 7.1979
# Loss_D: 0.9732, Loss_G: 0.3975
# Loss_D: 1.6843, Loss_G: 10.5774
# Loss_D: 3.9239, Loss_G: 0.7494
# Loss_D: 1.3337, Loss_G: 3.7925
# Loss_D: 0.7845, Loss_G: 2.3574
# Loss_D: 0.4924, Loss_G: 3.0918
# Loss_D: 1.0259, Loss_G: 5.2603
# Loss_D: 2.8445, Loss_G: 0.3719
# Loss_D: 2.3126, Loss_G: 5.3288
# Loss_D: 1.1759, Loss_G: 2.8241
# Loss_D: 0.5147, Loss_G: 2.6933
# Loss_D: 0.5094, Loss_G: 2.9998
# Loss_D: 0.5406, Loss_G: 3.2247
# Loss_D: 0.5886, Loss_G: 2.2736
# Loss_D: 0.6861, Loss_G: 2.6283
# Loss_D: 0.4425, Loss_G: 4.3362
# Loss_D: 0.7059, Loss_G: 1.4939
# Loss_D: 0.7197, Loss_G: 5.3035
# Loss_D: 0.5762, Loss_G: 2.9911
# Loss_D: 0.4029, Loss_G: 5.2687
